# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from plotly.subplots import make_subplots

from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
data = pd.read_csv('Gemini_ETHUSD_d.csv')
print(" Shape of the XRPUSDT 2023-2024 is: ", data.shape,"\n",
     "The number", data.shape[0], "shows number of samples and the",
     data.shape[1], "shows number of columns.")
data.head(10).style.set_properties(**{'background-color': '#b5caff',
                           'color': 'black',
                           'border-color': 'black'})
# Out:
#  Shape of the XRPUSDT 2023-2024 is:  (3600, 9)
#  The number 3600 shows number of samples and the 9 shows number of columns.
# <style type="text/css">
# #T_13676_row0_col0, #T_13676_row0_col1, #T_13676_row0_col2, #T_13676_row0_col3, #T_13676_row0_col4, #T_13676_row0_col5, #T_13676_row0_col6, #T_13676_row0_col7, #T_13676_row0_col8, #T_13676_row1_col0, #T_13676_row1_col1, #T_13676_row1_col2, #T_13676_row1_col3, #T_13676_row1_col4, #T_13676_row1_col5, #T_13676_row1_col6, #T_13676_row1_col7, #T_13676_row1_col8, #T_13676_row2_col0, #T_13676_row2_col1, #T_13676_row2_col2, #T_13676_row2_col3, #T_13676_row2_col4, #T_13676_row2_col5, #T_13676_row2_col6, #T_13676_row2_col7, #T_13676_row2_col8, #T_13676_row3_col0, #T_13676_row3_col1, #T_13676_row3_col2, #T_13676_row3_col3, #T_13676_row3_col4, #T_13676_row3_col5, #T_13676_row3_col6, #T_13676_row3_col7, #T_13676_row3_col8, #T_13676_row4_col0, #T_13676_row4_col1, #T_13676_row4_col2, #T_13676_row4_col3, #T_13676_row4_col4, #T_13676_row4_col5, #T_13676_row4_col6, #T_13676_row4_col7, #T_13676_row4_col8, #T_13676_row5_col0, #T_13676_row5_col1, #T_13676_row5_col2, #T_13676_row5_col3, #T_13676_row5_col4, #T_13676_row5_col5, #T_13676_row5_col6, #T_13676_row5_col7, #T_13676_row5_col8, #T_13676_row6_col0, #T_13676_row6_col1, #T_13676_row6_col2, #T_13676_row6_col3, #T_13676_row6_col4, #T_13676_row6_col5, #T_13676_row6_col6, #T_13676_row6_col7, #T_13676_row6_col8, #T_13676_row7_col0, #T_13676_row7_col1, #T_13676_row7_col2, #T_13676_row7_col3, #T_13676_row7_col4, #T_13676_row7_col5, #T_13676_row7_col6, #T_13676_row7_col7, #T_13676_row7_col8, #T_13676_row8_col0, #T_13676_row8_col1, #T_13676_row8_col2, #T_13676_row8_col3, #T_13676_row8_col4, #T_13676_row8_col5, #T_13676_row8_col6, #T_13676_row8_col7, #T_13676_row8_col8, #T_13676_row9_col0, #T_13676_row9_col1, #T_13676_row9_col2, #T_13676_row9_col3, #T_13676_row9_col4, #T_13676_row9_col5, #T_13676_row9_col6, #T_13676_row9_col7, #T_13676_row9_col8 {
#   background-color: #b5caff;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_13676">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13676_level0_col0" class="col_heading level0 col0" >unix</th>
#       <th id="T_13676_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_13676_level0_col2" class="col_heading level0 col2" >symbol</th>
#       <th id="T_13676_level0_col3" class="col_heading level0 col3" >open</th>
#       <th id="T_13676_level0_col4" class="col_heading level0 col4" >high</th>
#       <th id="T_13676_level0_col5" class="col_heading level0 col5" >low</th>
#       <th id="T_13676_level0_col6" class="col_heading level0 col6" >close</th>
#       <th id="T_13676_level0_col7" class="col_heading level0 col7" >Volume ETH</th>
#       <th id="T_13676_level0_col8" class="col_heading level0 col8" >Volume USD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13676_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13676_row0_col0" class="data row0 col0" >1743033600000</td>
#       <td id="T_13676_row0_col1" class="data row0 col1" >2025-03-27 00:00:00</td>
#       <td id="T_13676_row0_col2" class="data row0 col2" >ETH/USD</td>
#       <td id="T_13676_row0_col3" class="data row0 col3" >2009.210000</td>
#       <td id="T_13676_row0_col4" class="data row0 col4" >2037.360000</td>
#       <td id="T_13676_row0_col5" class="data row0 col5" >1986.790000</td>
#       <td id="T_13676_row0_col6" class="data row0 col6" >2001.790000</td>
#       <td id="T_13676_row0_col7" class="data row0 col7" >6326.901700</td>
#       <td id="T_13676_row0_col8" class="data row0 col8" >12665128.554043</td>
#     </tr>
#     <tr>
#       <th id="T_13676_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13676_row1_col0" class="data row1 col0" >1742947200000</td>
#       <td id="T_13676_row1_col1" class="data row1 col1" >2025-03-26 00:00:00</td>
#       <td id="T_13676_row1_col2" class="data row1 col2" >ETH/USD</td>
#       <td id="T_13676_row1_col3" class="data row1 col3" >2067.010000</td>
#       <td id="T_13676_row1_col4" class="data row1 col4" >2078.850000</td>
#       <td id="T_13676_row1_col5" class="data row1 col5" >1981.960000</td>
#       <td id="T_13676_row1_col6" class="data row1 col6" >2009.210000</td>
#       <td id="T_13676_row1_col7" class="data row1 col7" >5297.813974</td>
#       <td id="T_13676_row1_col8" class="data row1 col8" >10644420.814701</td>
#     </tr>
#     <tr>
#       <th id="T_13676_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13676_row2_col0" class="data row2 col0" >1742860800000</td>
#       <td id="T_13676_row2_col1" class="data row2 col1" >2025-03-25 00:00:00</td>
#       <td id="T_13676_row2_col2" class="data row2 col2" >ETH/USD</td>
#       <td id="T_13676_row2_col3" class="data row2 col3" >2081.380000</td>
#       <td id="T_13676_row2_col4" class="data row2 col4" >2097.340000</td>
#       <td id="T_13676_row2_col5" class="data row2 col5" >2037.930000</td>
#       <td id="T_13676_row2_col6" class="data row2 col6" >2067.010000</td>
#       <td id="T_13676_row2_col7" class="data row2 col7" >5937.018112</td>
#       <td id="T_13676_row2_col8" class="data row2 col8" >12271875.807685</td>
#     </tr>
#     <tr>
#       <th id="T_13676_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13676_row3_col0" class="data row3 col0" >1742774400000</td>
#       <td id="T_13676_row3_col1" class="data row3 col1" >2025-03-24 00:00:00</td>
#       <td id="T_13676_row3_col2" class="data row3 col2" >ETH/USD</td>
#       <td id="T_13676_row3_col3" class="data row3 col3" >2005.140000</td>
#       <td id="T_13676_row3_col4" class="data row3 col4" >2103.000000</td>
#       <td id="T_13676_row3_col5" class="data row3 col5" >1977.950000</td>
#       <td id="T_13676_row3_col6" class="data row3 col6" >2081.380000</td>
#       <td id="T_13676_row3_col7" class="data row3 col7" >8512.377211</td>
#       <td id="T_13676_row3_col8" class="data row3 col8" >17717491.679431</td>
#     </tr>
#     <tr>
#       <th id="T_13676_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13676_row4_col0" class="data row4 col0" >1742688000000</td>
#       <td id="T_13676_row4_col1" class="data row4 col1" >2025-03-23 00:00:00</td>
#       <td id="T_13676_row4_col2" class="data row4 col2" >ETH/USD</td>
#       <td id="T_13676_row4_col3" class="data row4 col3" >1979.950000</td>
#       <td id="T_13676_row4_col4" class="data row4 col4" >2020.000000</td>
#       <td id="T_13676_row4_col5" class="data row4 col5" >1976.920000</td>
#       <td id="T_13676_row4_col6" class="data row4 col6" >2005.140000</td>
#       <td id="T_13676_row4_col7" class="data row4 col7" >2530.927509</td>
#       <td id="T_13676_row4_col8" class="data row4 col8" >5074863.985396</td>
#     </tr>
#     <tr>
#       <th id="T_13676_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13676_row5_col0" class="data row5 col0" >1742601600000</td>
#       <td id="T_13676_row5_col1" class="data row5 col1" >2025-03-22 00:00:00</td>
#       <td id="T_13676_row5_col2" class="data row5 col2" >ETH/USD</td>
#       <td id="T_13676_row5_col3" class="data row5 col3" >1964.490000</td>
#       <td id="T_13676_row5_col4" class="data row5 col4" >2005.380000</td>
#       <td id="T_13676_row5_col5" class="data row5 col5" >1964.280000</td>
#       <td id="T_13676_row5_col6" class="data row5 col6" >1979.950000</td>
#       <td id="T_13676_row5_col7" class="data row5 col7" >1230.377888</td>
#       <td id="T_13676_row5_col8" class="data row5 col8" >2436086.699346</td>
#     </tr>
#     <tr>
#       <th id="T_13676_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13676_row6_col0" class="data row6 col0" >1742515200000</td>
#       <td id="T_13676_row6_col1" class="data row6 col1" >2025-03-21 00:00:00</td>
#       <td id="T_13676_row6_col2" class="data row6 col2" >ETH/USD</td>
#       <td id="T_13676_row6_col3" class="data row6 col3" >1983.010000</td>
#       <td id="T_13676_row6_col4" class="data row6 col4" >1994.750000</td>
#       <td id="T_13676_row6_col5" class="data row6 col5" >1937.180000</td>
#       <td id="T_13676_row6_col6" class="data row6 col6" >1964.490000</td>
#       <td id="T_13676_row6_col7" class=

# %%
df = pd.DataFrame(data)

df = df.rename(columns={'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close', 'Volume USD': 'Volume', 'date': 'Date'})
df = df[['Date','Open', 'High', 'Low', 'Close', 'Volume']]
df['Date'] = pd.to_datetime(df['Date'])
df['Volume'] = df['Volume'].astype('float64')
df.head(10).style.set_properties(**{'background-color': '#b5caff',
                           'color': 'black',
                           'border-color': 'black'})
# Out:
# <style type="text/css">
# #T_6763b_row0_col0, #T_6763b_row0_col1, #T_6763b_row0_col2, #T_6763b_row0_col3, #T_6763b_row0_col4, #T_6763b_row0_col5, #T_6763b_row1_col0, #T_6763b_row1_col1, #T_6763b_row1_col2, #T_6763b_row1_col3, #T_6763b_row1_col4, #T_6763b_row1_col5, #T_6763b_row2_col0, #T_6763b_row2_col1, #T_6763b_row2_col2, #T_6763b_row2_col3, #T_6763b_row2_col4, #T_6763b_row2_col5, #T_6763b_row3_col0, #T_6763b_row3_col1, #T_6763b_row3_col2, #T_6763b_row3_col3, #T_6763b_row3_col4, #T_6763b_row3_col5, #T_6763b_row4_col0, #T_6763b_row4_col1, #T_6763b_row4_col2, #T_6763b_row4_col3, #T_6763b_row4_col4, #T_6763b_row4_col5, #T_6763b_row5_col0, #T_6763b_row5_col1, #T_6763b_row5_col2, #T_6763b_row5_col3, #T_6763b_row5_col4, #T_6763b_row5_col5, #T_6763b_row6_col0, #T_6763b_row6_col1, #T_6763b_row6_col2, #T_6763b_row6_col3, #T_6763b_row6_col4, #T_6763b_row6_col5, #T_6763b_row7_col0, #T_6763b_row7_col1, #T_6763b_row7_col2, #T_6763b_row7_col3, #T_6763b_row7_col4, #T_6763b_row7_col5, #T_6763b_row8_col0, #T_6763b_row8_col1, #T_6763b_row8_col2, #T_6763b_row8_col3, #T_6763b_row8_col4, #T_6763b_row8_col5, #T_6763b_row9_col0, #T_6763b_row9_col1, #T_6763b_row9_col2, #T_6763b_row9_col3, #T_6763b_row9_col4, #T_6763b_row9_col5 {
#   background-color: #b5caff;
#   color: black;
#   border-color: black;
# }
# </style>
# <table id="T_6763b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6763b_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_6763b_level0_col1" class="col_heading level0 col1" >Open</th>
#       <th id="T_6763b_level0_col2" class="col_heading level0 col2" >High</th>
#       <th id="T_6763b_level0_col3" class="col_heading level0 col3" >Low</th>
#       <th id="T_6763b_level0_col4" class="col_heading level0 col4" >Close</th>
#       <th id="T_6763b_level0_col5" class="col_heading level0 col5" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6763b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6763b_row0_col0" class="data row0 col0" >2025-03-27 00:00:00</td>
#       <td id="T_6763b_row0_col1" class="data row0 col1" >2009.210000</td>
#       <td id="T_6763b_row0_col2" class="data row0 col2" >2037.360000</td>
#       <td id="T_6763b_row0_col3" class="data row0 col3" >1986.790000</td>
#       <td id="T_6763b_row0_col4" class="data row0 col4" >2001.790000</td>
#       <td id="T_6763b_row0_col5" class="data row0 col5" >12665128.554043</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6763b_row1_col0" class="data row1 col0" >2025-03-26 00:00:00</td>
#       <td id="T_6763b_row1_col1" class="data row1 col1" >2067.010000</td>
#       <td id="T_6763b_row1_col2" class="data row1 col2" >2078.850000</td>
#       <td id="T_6763b_row1_col3" class="data row1 col3" >1981.960000</td>
#       <td id="T_6763b_row1_col4" class="data row1 col4" >2009.210000</td>
#       <td id="T_6763b_row1_col5" class="data row1 col5" >10644420.814701</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6763b_row2_col0" class="data row2 col0" >2025-03-25 00:00:00</td>
#       <td id="T_6763b_row2_col1" class="data row2 col1" >2081.380000</td>
#       <td id="T_6763b_row2_col2" class="data row2 col2" >2097.340000</td>
#       <td id="T_6763b_row2_col3" class="data row2 col3" >2037.930000</td>
#       <td id="T_6763b_row2_col4" class="data row2 col4" >2067.010000</td>
#       <td id="T_6763b_row2_col5" class="data row2 col5" >12271875.807685</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6763b_row3_col0" class="data row3 col0" >2025-03-24 00:00:00</td>
#       <td id="T_6763b_row3_col1" class="data row3 col1" >2005.140000</td>
#       <td id="T_6763b_row3_col2" class="data row3 col2" >2103.000000</td>
#       <td id="T_6763b_row3_col3" class="data row3 col3" >1977.950000</td>
#       <td id="T_6763b_row3_col4" class="data row3 col4" >2081.380000</td>
#       <td id="T_6763b_row3_col5" class="data row3 col5" >17717491.679431</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6763b_row4_col0" class="data row4 col0" >2025-03-23 00:00:00</td>
#       <td id="T_6763b_row4_col1" class="data row4 col1" >1979.950000</td>
#       <td id="T_6763b_row4_col2" class="data row4 col2" >2020.000000</td>
#       <td id="T_6763b_row4_col3" class="data row4 col3" >1976.920000</td>
#       <td id="T_6763b_row4_col4" class="data row4 col4" >2005.140000</td>
#       <td id="T_6763b_row4_col5" class="data row4 col5" >5074863.985396</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6763b_row5_col0" class="data row5 col0" >2025-03-22 00:00:00</td>
#       <td id="T_6763b_row5_col1" class="data row5 col1" >1964.490000</td>
#       <td id="T_6763b_row5_col2" class="data row5 col2" >2005.380000</td>
#       <td id="T_6763b_row5_col3" class="data row5 col3" >1964.280000</td>
#       <td id="T_6763b_row5_col4" class="data row5 col4" >1979.950000</td>
#       <td id="T_6763b_row5_col5" class="data row5 col5" >2436086.699346</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6763b_row6_col0" class="data row6 col0" >2025-03-21 00:00:00</td>
#       <td id="T_6763b_row6_col1" class="data row6 col1" >1983.010000</td>
#       <td id="T_6763b_row6_col2" class="data row6 col2" >1994.750000</td>
#       <td id="T_6763b_row6_col3" class="data row6 col3" >1937.180000</td>
#       <td id="T_6763b_row6_col4" class="data row6 col4" >1964.490000</td>
#       <td id="T_6763b_row6_col5" class="data row6 col5" >7794173.632443</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6763b_row7_col0" class="data row7 col0" >2025-03-20 00:00:00</td>
#       <td id="T_6763b_row7_col1" class="data row7 col1" >2057.410000</td>
#       <td id="T_6763b_row7_col2" class="data row7 col2" >2067.810000</td>
#       <td id="T_6763b_row7_col3" class="data row7 col3" >1951.340000</td>
#       <td id="T_6763b_row7_col4" class="data row7 col4" >1983.010000</td>
#       <td id="T_6763b_row7_col5" class="data row7 col5" >11671835.940722</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6763b_row8_col0" class="data row8 col0" >2025-03-19 00:00:00</td>
#       <td id="T_6763b_row8_col1" class="data row8 col1" >1931.380000</td>
#       <td id="T_6763b_row8_col2" class="data row8 col2" >2070.000000</td>
#       <td id="T_6763b_row8_col3" class="data row8 col3" >1928.030000</td>
#       <td id="T_6763b_row8_col4" class="data row8 col4" >2057.410000</td>
#       <td id="T_6763b_row8_col5" class="data row8 col5" >20149676.771770</td>
#     </tr>
#     <tr>
#       <th id="T_6763b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6763b_row9_col0" class="data row9 col0" >2025-03-18 00:00:00</td>
#       <td id="T_6763b_row9_col1" class="data row9 col1" >1926.510000</td>
#       <td id="T_6763b_row9_col2" class="data row9 col2" >1935.360000</td>
#       <td id="T_6763b_row9_col3" class="data row9 col3" >1872.250000</td>
#       <td id="T_6763b_row9_col4" class="data row9 col4" >1931.380000</td>
#       <td id="T_6763b_row9_col5" class="data row9 col5" >10234646.919696</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.dates as mdates

# Optional: ensure seaborn style is applied
sns.set(style="whitegrid")

# Convert to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Create figure and axes
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8), sharex=True, 
                               gridspec_kw={'height_ratios': [3, 1], 'hspace': 0.05})

# --- Candlestick chart ---
# We draw candlesticks manually using rectangles and lines
for idx, row in df.iterrows():
    color = 'green' if row['Close'] >= row['Open'] else 'red'
    # Wick (high-low line)
    ax1.plot([row['Date'], row['Date']], [row['Low'], row['High']], color=color, linewidth=1)
    # Body (open-close box)
    ax1.add_patch(plt.Rectangle(
        (row['Date'], min(row['Open'], row['Close'])),
        width=pd.Timedelta('1d'),  # Adjust width based on data frequency
        height=abs(row['Open'] - row['Close']),
        color=color
    ))

ax1.set_ylabel("ETHUSDT")
ax1.set_title("Ripple")

# Vertical line shape (from x0 to x1 at full height)
ax1.axvline(pd.to_datetime("2016-05-09"), color='blue', linestyle='--', linewidth=1)
ax1.axvline(pd.to_datetime("2025-03-27"), color='blue', linestyle='--', linewidth=1)

# Format x-axis
ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=6))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45)

# --- Volume chart ---
ax2.plot(df['Date'], df['Volume'], linewidth=1.5, color='blue')
ax2.set_ylabel("Volume")
ax2.set_title("Volume")

plt.show()

# %%
df["5d_sma"] = df["Close"].rolling(5).mean()
df["9d_sma"] = df["Close"].rolling(9).mean()
df["20d_sma"] = df["Close"].rolling(20).mean()

#For the first few vaules, the moving average will be NaN
df['5d_sma'] = df['5d_sma'].fillna(df['Close'])
df['9d_sma'] = df['9d_sma'].fillna(df['Close'])
df['20d_sma'] = df['20d_sma'].fillna(df['Close'])

df
# Out:
#                     Date     Open     High      Low    Close        Volume  \
# 0    2025-03-27 00:00:00  2009.21  2037.36  1986.79  2001.79  1.266513e+07
# 1    2025-03-26 00:00:00  2067.01  2078.85  1981.96  2009.21  1.064442e+07
# 2    2025-03-25 00:00:00  2081.38  2097.34  2037.93  2067.01  1.227188e+07
# 3    2025-03-24 00:00:00  2005.14  2103.00  1977.95  2081.38  1.771749e+07
# 4    2025-03-23 00:00:00  1979.95  2020.00  1976.92  2005.14  5.074864e+06
# ...                  ...      ...      ...      ...      ...           ...
# 3595 2016-05-13 04:00:00    10.40    11.59    10.20    10.50  1.877445e+04
# 3596 2016-05-12 04:00:00    10.45    12.00     9.92    10.40  2.143453e+04
# 3597 2016-05-11 04:00:00     9.74    10.47     9.69    10.45  3.218110e+04
# 3598 2016-05-10 04:00:00     9.36     9.95     9.36     9.74  7.447480e+03
# 3599 2016-05-09 04:00:00     0.00    12.00     0.00     9.36  1.288511e+04
#
#         5d_sma       9d_sma    20d_sma
# 0     2001.790  2001.790000  2001.7900
# 1     2009.210  2009.210000  2009.2100
# 2     2067.010  2067.010000  2067.0100
# 3     2081.380  2081.380000  2081.3800
# 4     2032.906  2005.140000  2005.1400
# ...        ...          ...        ...
# 3595    11.100    12.373333    12.6040
# 3596    10.572    11.957778    12.4315
# 3597    10.396    11.642222    12.2475
# 3598    10.332    11.106667    12.1040
# 3599    10.090    10.605556    11.9505
#
# [3600 rows x 9 columns]

# %%
plt.figure(figsize=(20,10), dpi=200)
plt.plot(df['Date'], df['Close'], label='XRPUSDT')
plt.plot(df['Date'], df['5d_sma'], label='SMA 5')
plt.plot(df['Date'], df['9d_sma'], label='SMA 9')
plt.plot(df['Date'], df['20d_sma'], label='SMA 20')
plt.title('ETHUSDT')
plt.ylabel('Price')
plt.xlabel('Date')
plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
num_std = 4
sma_periods = [5, 9, 20]

for period in sma_periods:
    sma_col = f'{period}d_sma'

    # Use SMA as rolling mean
    rolling_mean = df[sma_col]

    # Compute rolling std from original 'Close' over the same period
    rolling_std = df['Close'].rolling(window=period).std()

    # Bollinger Bands
    upper_band = rolling_mean + num_std * rolling_std
    lower_band = rolling_mean - num_std * rolling_std

    # Plotting
    plt.figure(figsize=(20, 7))
    plt.plot(df['Close'], label='Stock Price', color='red', alpha=0.5)
    plt.plot(rolling_mean, label=f'{period}d SMA', color='blue')
    plt.plot(upper_band, label='Upper Band', color='green', linestyle='--')
    plt.plot(lower_band, label='Lower Band', color='green', linestyle='--')
    plt.fill_between(df.index, lower_band, upper_band, color='grey', alpha=0.2)
    plt.title(f'Bollinger Bands (Base: {period}d SMA)')
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
df['Days'] = df.index + 1

_5d = df[['Open','High','Low','Days', '5d_sma','Volume','Close']].copy(deep=True)
_9d = df[['Open','High','Low','Days', '9d_sma','Volume','Close']].copy(deep=True)
_20d = df[['Open','High','Low','Days', '20d_sma','Volume','Close']].copy(deep=True)
_all = df[['Open','High','Low','Days', '5d_sma', '9d_sma', '20d_sma','Volume','Close']].copy(deep=True)

scaler = MinMaxScaler(feature_range=(0,2)).fit(_5d.Low.values.reshape(-1,1))
_5d['Open'] = scaler.transform(_5d.Open.values.reshape(-1,1))
_5d['High'] = scaler.transform(_5d.High.values.reshape(-1,1))
_5d['Low'] = scaler.transform(_5d.Low.values.reshape(-1,1))
_5d['Close'] = scaler.transform(_5d.Close.values.reshape(-1,1))
_5d['Volume'] = scaler.transform(_5d.Volume.values.reshape(-1,1))
_5d['Days'] = scaler.transform(_5d.Days.values.reshape(-1,1))
_5d['5d_sma'] = scaler.transform(_5d['5d_sma'].values.reshape(-1,1))

scaler = MinMaxScaler(feature_range=(0,2)).fit(_9d.Low.values.reshape(-1,1))
_9d['Open'] = scaler.transform(_9d.Open.values.reshape(-1,1))
_9d['High'] = scaler.transform(_9d.High.values.reshape(-1,1))
_9d['Low'] = scaler.transform(_9d.Low.values.reshape(-1,1))
_9d['Close'] = scaler.transform(_9d.Close.values.reshape(-1,1))
_9d['Volume'] = scaler.transform(_9d.Volume.values.reshape(-1,1))
_9d['Days'] = scaler.transform(_9d.Days.values.reshape(-1,1))
_9d['9d_sma'] = scaler.transform(_9d['9d_sma'].values.reshape(-1,1))

scaler = MinMaxScaler(feature_range=(0,2)).fit(_20d.Low.values.reshape(-1,1))
_20d['Open'] = scaler.transform(_20d.Open.values.reshape(-1,1))
_20d['High'] = scaler.transform(_20d.High.values.reshape(-1,1))
_20d['Low'] = scaler.transform(_20d.Low.values.reshape(-1,1))
_20d['Close'] = scaler.transform(_20d.Close.values.reshape(-1,1))
_20d['Volume'] = scaler.transform(_20d.Volume.values.reshape(-1,1))
_20d['Days'] = scaler.transform(_20d.Days.values.reshape(-1,1))
_20d['20d_sma'] = scaler.transform(_20d['20d_sma'].values.reshape(-1,1))

scaler = MinMaxScaler(feature_range=(0,2)).fit(_all.Low.values.reshape(-1,1))
_all['Open'] = scaler.transform(_all.Open.values.reshape(-1,1))
_all['High'] = scaler.transform(_all.High.values.reshape(-1,1))
_all['Low'] = scaler.transform(_all.Low.values.reshape(-1,1))
_all['Close'] = scaler.transform(_all.Close.values.reshape(-1,1))
_all['Volume'] = scaler.transform(_all.Volume.values.reshape(-1,1))
_all['Days'] = scaler.transform(_all.Days.values.reshape(-1,1))
_all['5d_sma'] = scaler.transform(_all['5d_sma'].values.reshape(-1,1))
_all['9d_sma'] = scaler.transform(_all['9d_sma'].values.reshape(-1,1))
_all['20d_sma'] = scaler.transform(_all['20d_sma'].values.reshape(-1,1))


data_5d_all = _5d[['Open','High','Low','Close', '5d_sma', 'Volume', 'Days']].values
data_5d = _5d[['Open','High','Low','Close', '5d_sma']].values
data_9d = _9d[['Open','High','Low', '9d_sma','Close']].values
data_20d = _20d[['Open','High','Low', '20d_sma','Close']].values
data_all = _all[['Open','High','Low', '5d_sma', '9d_sma', '20d_sma','Close']].values

print(data_5d_all.shape)
print(data_5d.shape)
print(data_9d.shape)
print(data_20d.shape)
print(data_all.shape)
# Out:
# (3600, 7)
# (3600, 5)
# (3600, 5)
# (3600, 5)
# (3600, 7)

# %%
seq_len= 11
sequences_5d_all=[]
for index in range(len(data_5d_all) - seq_len + 1): 
    sequences_5d_all.append(data_5d_all[index: index + seq_len])
sequences_5d_all = np.array(sequences_5d_all)
print(sequences_5d_all.shape)


seq_len= 11
sequences_5d=[]
for index in range(len(data_5d) - seq_len + 1): 
    sequences_5d.append(data_5d[index: index + seq_len])
sequences_5d = np.array(sequences_5d)
print(sequences_5d.shape)


sequences_9d=[]
for index in range(len(data_9d) - seq_len + 1): 
    sequences_9d.append(data_9d[index: index + seq_len])
sequences_9d = np.array(sequences_9d)
print(sequences_9d.shape)


sequences_20d=[]
for index in range(len(data_20d) - seq_len + 1): 
    sequences_20d.append(data_20d[index: index + seq_len])
sequences_20d = np.array(sequences_20d)
print(sequences_20d.shape)


sequences_all=[]
for index in range(len(data_all) - seq_len + 1): 
    sequences_all.append(data_all[index: index + seq_len])
sequences_all = np.array(sequences_all)
print(sequences_all.shape)
# Out:
# (3590, 11, 7)
# (3590, 11, 5)
# (3590, 11, 5)
# (3590, 11, 5)
# (3590, 11, 7)

# %%
valid_set_size_percentage = 10 
test_set_size_percentage = 10 


valid_set_size_5d_all = int(np.round(valid_set_size_percentage/100*sequences_5d_all.shape[0]))  
test_set_size_5d_all  = int(np.round(test_set_size_percentage/100*sequences_5d_all.shape[0]))
train_set_size_5d_all = sequences_5d_all.shape[0] - (valid_set_size_5d_all + test_set_size_5d_all)
print("train_set_size_5d_all", test_set_size_5d_all)

x_train_5d_all = sequences_5d_all[:train_set_size_5d_all,:-1,:]
y_train_5d_all = sequences_5d_all[:train_set_size_5d_all,-1,:]
    
x_valid_5d_all = sequences_5d_all[train_set_size_5d_all:train_set_size_5d_all+valid_set_size_5d_all,
                                  :-1,:]
y_valid_5d_all = sequences_5d_all[train_set_size_5d_all:train_set_size_5d_all+valid_set_size_5d_all
                                  ,-1,:]
    
x_test_5d_all = sequences_5d_all[train_set_size_5d_all+valid_set_size_5d_all:,:-1,:]
y_test_5d_all = sequences_5d_all[train_set_size_5d_all+valid_set_size_5d_all:,-1,:]



valid_set_size_5d = int(np.round(valid_set_size_percentage/100*sequences_5d.shape[0]))  
test_set_size_5d  = int(np.round(test_set_size_percentage/100*sequences_5d.shape[0]))
train_set_size_5d = sequences_5d.shape[0] - (valid_set_size_5d + test_set_size_5d)

x_train_5d = sequences_5d[:train_set_size_5d,:-1,:]
y_train_5d = sequences_5d[:train_set_size_5d,-1,:]
    
x_valid_5d = sequences_5d[train_set_size_5d:train_set_size_5d+valid_set_size_5d,:-1,:]
y_valid_5d = sequences_5d[train_set_size_5d:train_set_size_5d+valid_set_size_5d,-1,:]
    
x_test_5d = sequences_5d[train_set_size_5d+valid_set_size_5d:,:-1,:]
y_test_5d = sequences_5d[train_set_size_5d+valid_set_size_5d:,-1,:]



valid_set_size_9d = int(np.round(valid_set_size_percentage/100*sequences_9d.shape[0]))  
test_set_size_9d  = int(np.round(test_set_size_percentage/100*sequences_9d.shape[0]))
train_set_size_9d = sequences_9d.shape[0] - (valid_set_size_9d + test_set_size_9d)

x_train_9d = sequences_9d[:train_set_size_9d,:-1,:]
y_train_9d = sequences_9d[:train_set_size_9d,-1,:]
    
x_valid_9d = sequences_9d[train_set_size_9d:train_set_size_9d+valid_set_size_9d,:-1,:]
y_valid_9d = sequences_9d[train_set_size_9d:train_set_size_9d+valid_set_size_9d,-1,:]
    
x_test_9d = sequences_9d[train_set_size_9d+valid_set_size_9d:,:-1,:]
y_test_9d = sequences_9d[train_set_size_9d+valid_set_size_9d:,-1,:]



valid_set_size_20d = int(np.round(valid_set_size_percentage/100*sequences_20d.shape[0]))  
test_set_size_20d  = int(np.round(test_set_size_percentage/100*sequences_20d.shape[0]))
train_set_size_20d = sequences_20d.shape[0] - (valid_set_size_20d + test_set_size_20d)

x_train_20d = sequences_20d[:train_set_size_20d,:-1,:]
y_train_20d = sequences_20d[:train_set_size_20d,-1,:]
    
x_valid_20d = sequences_20d[train_set_size_20d:train_set_size_20d+valid_set_size_20d,:-1,:]
y_valid_20d = sequences_20d[train_set_size_20d:train_set_size_20d+valid_set_size_20d,-1,:]
    
x_test_20d = sequences_20d[train_set_size_20d+valid_set_size_20d:,:-1,:]
y_test_20d = sequences_20d[train_set_size_20d+valid_set_size_20d:,-1,:]



valid_set_size_all = int(np.round(valid_set_size_percentage/100*sequences_all.shape[0]))  
test_set_size_all  = int(np.round(test_set_size_percentage/100*sequences_all.shape[0]))
train_set_size_all = sequences_5d.shape[0] - (valid_set_size_all + test_set_size_all)

x_train_all = sequences_all[:train_set_size_all,:-1,:]
y_train_all = sequences_all[:train_set_size_all,-1,:]
    
x_valid_all = sequences_all[train_set_size_all:train_set_size_all+valid_set_size_all,:-1,:]
y_valid_all = sequences_all[train_set_size_all:train_set_size_all+valid_set_size_all,-1,:]
    
x_test_all = sequences_all[train_set_size_all+valid_set_size_all:,:-1,:]
y_test_all = sequences_all[train_set_size_all+valid_set_size_all:,-1,:]
# Out:
# train_set_size_5d_all 359

# %%
x_train_5d_all = torch.tensor(x_train_5d_all).float()
y_train_5d_all = torch.tensor(y_train_5d_all).float()

x_valid_5d_all = torch.tensor(x_valid_5d_all).float()
y_valid_5d_all = torch.tensor(y_valid_5d_all).float()

train_dataset_5d_all = TensorDataset(x_train_5d_all,y_train_5d_all)
train_dataloader_5d_all = DataLoader(train_dataset_5d_all, batch_size=32, shuffle=False)

valid_dataset_5d_all = TensorDataset(x_valid_5d_all,y_valid_5d_all)
valid_dataloader_5d_all = DataLoader(valid_dataset_5d_all, batch_size=32, shuffle=False)




x_train_5d = torch.tensor(x_train_5d).float()
y_train_5d = torch.tensor(y_train_5d).float()

x_valid_5d = torch.tensor(x_valid_5d).float()
y_valid_5d = torch.tensor(y_valid_5d).float()

train_dataset_5d = TensorDataset(x_train_5d,y_train_5d)
train_dataloader_5d = DataLoader(train_dataset_5d, batch_size=32, shuffle=False)

valid_dataset_5d = TensorDataset(x_valid_5d,y_valid_5d)
valid_dataloader_5d = DataLoader(valid_dataset_5d, batch_size=32, shuffle=False)



x_train_9d = torch.tensor(x_train_9d).float()
y_train_9d = torch.tensor(y_train_9d).float()

x_valid_9d = torch.tensor(x_valid_9d).float()
y_valid_9d = torch.tensor(y_valid_9d).float()

train_dataset_9d = TensorDataset(x_train_9d,y_train_9d)
train_dataloader_9d = DataLoader(train_dataset_9d, batch_size=32, shuffle=False)

valid_dataset_9d = TensorDataset(x_valid_9d,y_valid_9d)
valid_dataloader_9d = DataLoader(valid_dataset_9d, batch_size=32, shuffle=False)



x_train_20d = torch.tensor(x_train_20d).float()
y_train_20d = torch.tensor(y_train_20d).float()

x_valid_20d = torch.tensor(x_valid_20d).float()
y_valid_20d = torch.tensor(y_valid_20d).float()

train_dataset_20d = TensorDataset(x_train_20d,y_train_20d)
train_dataloader_20d = DataLoader(train_dataset_20d, batch_size=32, shuffle=False)

valid_dataset_20d = TensorDataset(x_valid_20d,y_valid_20d)
valid_dataloader_20d = DataLoader(valid_dataset_20d, batch_size=32, shuffle=False)



x_train_all = torch.tensor(x_train_all).float()
y_train_all = torch.tensor(y_train_all).float()

x_valid_all = torch.tensor(x_valid_all).float()
y_valid_all = torch.tensor(y_valid_all).float()

train_dataset_all = TensorDataset(x_train_all,y_train_all)
train_dataloader_all = DataLoader(train_dataset_all, batch_size=32, shuffle=False)

valid_dataset_all = TensorDataset(x_valid_all,y_valid_all)
valid_dataloader_all = DataLoader(valid_dataset_all, batch_size=32, shuffle=False)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, num_feature):
        super(NeuralNetwork, self).__init__()
        self.lstm  = nn.LSTM(num_feature,64,batch_first=True)
        self.fc    = nn.Linear(64,num_feature)
        
        
    def forward(self, x):
        output, (hidden, cell) = self.lstm(x)
        x = self.fc(hidden)
        return x


model_5d_all = NeuralNetwork(7)


optimizer = optim.Adam(model_5d_all.parameters())
mse = nn.MSELoss()


def train(dataloader):
    epoch_loss = 0
    model_5d_all.train()  
    
    for batch in dataloader:
        optimizer.zero_grad()          
        x,y= batch
        pred = model_5d_all(x)
        loss = mse(pred[0],y)        
        loss.backward()               
        optimizer.step()      
        epoch_loss += loss.item()  
        
    return epoch_loss

def evaluate(dataloader):
    epoch_loss = 0
    model_5d_all.eval()  
    
    with torch.no_grad():
        for batch in dataloader:   
            x,y= batch
            pred = model_5d_all(x)
            loss = mse(pred[0],y)              
            epoch_loss += loss.item()  
        
    return epoch_loss / len(dataloader)

# %%
n_epochs = 100
best_valid_loss_5d_all = float('inf')

for epoch in range(1, n_epochs + 1):

    train_loss_5d_all = train(train_dataloader_5d_all)
    valid_loss_5d_all = evaluate(valid_dataloader_5d_all)
    
    #save the best model
    if valid_loss_5d_all < best_valid_loss_5d_all:
        best_valid_loss_5d_all = valid_loss_5d_all
        torch.save(model_5d_all, 'saved_weights_5d_all.pt')

    # print("Epoch ",epoch+1)
    print(f'\tTrain Loss: {train_loss_5d_all:.5f} | ' + f'\tVal Loss: {valid_loss_5d_all:.5f}\n')
# Out:
# 	Train Loss: 3032296275.85938 | 	Val Loss: 54774590.23438
#
# 	Train Loss: 3031642239.62500 | 	Val Loss: 54758857.97656
#
# 	Train Loss: 3030471075.16406 | 	Val Loss: 54733710.52083
#
# 	Train Loss: 3029088447.42188 | 	Val Loss: 54710328.39583
#
# 	Train Loss: 3027636780.92969 | 	Val Loss: 54680644.85938
#
# 	Train Loss: 3026131887.57812 | 	Val Loss: 54658444.96875
#
# 	Train Loss: 3024978054.55469 | 	Val Loss: 54639243.09115
#
# 	Train Loss: 3023919793.20312 | 	Val Loss: 54621029.18229
#
# 	Train Loss: 3022905773.53125 | 	Val Loss: 54603393.32552
#
# 	Train Loss: 3021919617.77344 | 	Val Loss: 54586155.07031
#
# 	Train Loss: 3020952946.37500 | 	Val Loss: 54569199.59115
#
# 	Train Loss: 3020000492.56250 | 	Val Loss: 54552461.00781
#
# 	Train Loss: 3019059599.11719 | 	Val Loss: 54535892.71615
#
# 	Train Loss: 3018127465.57812 | 	Val Loss: 54519460.74479
#
# 	Train Loss: 3017202915.45312 | 	Val Loss: 54503148.01302
#
# 	Train Loss: 3016284439.28906 | 	Val Loss: 54486928.82292
#
# 	Train Loss: 3015371249.00000 | 	Val Loss: 54470792.67969
#
# 	Train Loss: 3014462682.53906 | 	Val Loss: 54454729.11719
#
# 	Train Loss: 3013558062.57031 | 	Val Loss: 54438730.16406
#
# 	Train Loss: 3012656903.39844 | 	Val Loss: 54422782.09635
#
# 	Train Loss: 3011758920.64062 | 	Val Loss: 54406886.25000
#
# 	Train Loss: 3010863726.24219 | 	Val Loss: 54391035.03906
#
# 	Train Loss: 3009971042.60938 | 	Val Loss: 54375220.27604
#
# 	Train Loss: 3009080539.73438 | 	Val Loss: 54359446.49479
#
# 	Train Loss: 3008192264.57031 | 	Val Loss: 54343698.44792
#
# 	Train Loss: 3007305907.90625 | 	Val Loss: 54327983.78906
#
# 	Train Loss: 3006421238.46875 | 	Val Loss: 54312296.02604
#
# 	Train Loss: 3005538226.63281 | 	Val Loss: 54296636.42708
#
# 	Train Loss: 3004656871.88281 | 	Val Loss: 54280997.20312
#
# 	Train Loss: 3003776947.29688 | 	Val Loss: 54265381.23177
#
# 	Train Loss: 3002898305.96875 | 	Val Loss: 54249788.41406
#
# 	Train Loss: 3002021069.39844 | 	Val Loss: 54234212.65885
#
# 	Train Loss: 3001144901.51562 | 	Val Loss: 54218654.76042
#
# 	Train Loss: 3000269965.24219 | 	Val Loss: 54203116.40625
#
# 	Train Loss: 2999396135.60156 | 	Val Loss: 54187590.90885
#
# 	Train Loss: 2998523379.94531 | 	Val Loss: 54172084.61719
#
# 	Train Loss: 2997651623.24609 | 	Val Loss: 54156593.91927
#
# 	Train Loss: 2996780818.54297 | 	Val Loss: 54141115.83594
#
# 	Train Loss: 2995911027.78516 | 	Val Loss: 54125648.68229
#
# 	Train Loss: 2995042142.83984 | 	Val Loss: 54110200.08854
#
# 	Train Loss: 2994174203.78125 | 	Val Loss: 54094758.29427
#
# 	Train Loss: 2993306891.12109 | 	Val Loss: 54079335.89844
#
# 	Train Loss: 2992440626.44922 | 	Val Loss: 54063921.41927
#
# 	Train Loss: 2991574997.46484 | 	Val Loss: 54048518.12500
#
# 	Train Loss: 2990710340.29688 | 	Val Loss: 54033132.23958
#
# 	Train Loss: 2989846383.57812 | 	Val Loss: 54017750.38281
#
# 	Train Loss: 2988983125.55078 | 	Val Loss: 54002381.16406
#
# 	Train Loss: 2988120761.39453 | 	Val Loss: 53987022.36458
#
# 	Train Loss: 2987259044.51953 | 	Val Loss: 53971675.76823
#
# 	Train Loss: 2986398108.03125 | 	Val Loss: 53956337.47917
#
# 	Train Loss: 2985537753.73438 | 	Val Loss: 53941010.54427
#
# 	Train Loss: 2984678153.70703 | 	Val Loss: 53925694.62240
#
# 	Train Loss: 2983819361.78125 | 	Val Loss: 53910383.81250
#
# 	Train Loss: 2982961146.85547 | 	Val Loss: 53895087.99740
#
# 	Train Loss: 2982103760.55078 | 	Val Loss: 53879796.87760
#
# 	Train Loss: 2981246907.83984 | 	Val Loss: 53864519.50260
#
# 	Train Loss: 2980390696.53906 | 	Val Loss: 53849246.36458
#
# 	Train Loss: 2979535182.24609 | 	Val Loss: 53833986.59115
#
# 	Train Loss: 2978680363.02344 | 	Val Loss: 53818734.26562
#
# 	Train Loss: 2977826122.97266 | 	Val Loss: 53803490.50521
#
# 	Train Loss: 2976972686.19922 | 	Val Loss: 53788258.54167
#
# 	Train Loss: 2976119723.19531 | 	Val Loss: 53773030.82812
#
# 	Train Loss: 2975267458.01172 | 	Val Loss: 53757813.38021
#
# 	Train Loss: 2974415879.39453 | 	Val Loss: 53742604.61719
#
# 	Train Loss: 2973564909.46094 | 	Val Loss: 53727407.16406
#
# 	Train Loss: 2972714574.01953 | 	Val Loss: 53712214.86719
#
# 	Train Loss: 2971864740.74609 | 	Val Loss: 53697034.83333
#
# 	Train Loss: 2971015662.67188 | 	Val Loss: 53681862.84635
#
# 	Train Loss: 2970167266.86719 | 	Val Loss: 53666691.50000
#
# 	Train Loss: 2969319307.84375 | 	Val Loss: 53651537.51562
#
# 	Train Loss: 2968472169.75000 | 	Val Loss: 53636387.18750
#
# 	Train Loss: 2967625512.03906 | 	Val Loss: 53621249.09115
#
# 	Train Loss: 2966779559.03906 | 	Val Loss: 53606118.84635
#
# 	Train Loss: 2965933980.89062 | 	Val Loss: 53590996.10156
#
# 	Train Loss: 2965089358.89844 | 	Val Loss: 53575881.14323
#
# 	Train Loss: 2964245161.66016 | 	Val Loss: 53560775.96875
#
# 	Train Loss: 2963401567.62891 | 	Val Loss: 53545676.76823
#
# 	Train Loss: 2962558660.78516 | 	Val Loss: 53530586.59115
#
# 	Train Loss: 2961716231.32031 | 	Val Loss: 53515503.94792
#
# 	Train Loss: 2960874457.33984 | 	Val Loss: 53500432.02604
#
# 	Train Loss: 2960033297.76953 | 	Val Loss: 53485366.64062
#
# 	Train Loss: 2959192901.98828 | 	Val Loss: 53470310.60156
#
# 	Train Loss: 2958352884.16797 | 	Val Loss: 53455263.60677
#
# 	Train Loss: 2957513564.36328 | 	Val Loss: 53440217.96875
#
# 	Train Loss: 2956674819.12891 | 	Val Loss: 53425189.10417
#
# 	Train Loss: 2955836745.58203 | 	Val Loss: 53410162.83333
#
# 	Train Loss: 2954999268.35938 | 	Val Loss: 53395147.71875
#
# 	Train Loss: 2954162293.98438 | 	Val Loss: 53380140.86719
#
# 	Train Loss: 2953326096.65234 | 	Val Loss: 53365144.19271
#
# 	Train Loss: 2952490277.11328 | 	Val Loss: 53350147.54427
#
# 	Train Loss: 2951655172.98438 | 	Val Loss: 53335168.17188
#
# 	Train Loss: 2950820690.40625 | 	Val Loss: 53320191.95833
#
# 	Train Loss: 2949986736.17188 | 	Val Loss: 53305226.72396
#
# 	Train Loss: 2949153455.86328 | 	Val Loss: 53290268.73438
#
# 	Train Loss: 2948320823.40625 | 	Val Loss: 53275313.63021
#
# 	Train Loss: 2947488689.21094 | 	Val Loss: 53260373.03906
#
# 	Train Loss: 2946657124.75781 | 	Val Loss: 53245438.17969
#
# 	Train Loss: 2945826281.43750 | 	Val Loss: 53230512.85938
#
# 	Train Loss: 2944995845.69141 | 	Val Loss: 53215591.50260
#
# 	Train Loss: 2944166145.26562 | 	Val Loss: 53200685.47135

# %%
model_5d_all =torch.load('saved_weights_5d_all.pt', weights_only=False)


x_test_5d_all = torch.tensor(x_test_5d_all).float()

with torch.no_grad():
    y_test_pred_5d_all = model_5d_all(x_test_5d_all)

y_test_pred_5d_all = y_test_pred_5d_all.numpy()[0]

idx=0
plt.figure(figsize=(15,5), dpi=200)
plt.plot(np.arange(y_train_5d_all.shape[0], y_train_5d_all.shape[0]+y_test_5d_all.shape[0]),
         y_test_5d_all[:,idx], color='blue', label='test target')

plt.plot(np.arange(y_train_5d_all.shape[0], y_train_5d_all.shape[0]+y_test_pred_5d_all.shape[0]),
         y_test_pred_5d_all[:,idx], color='red', label='test prediction')

plt.title('future XRPUSDT prices')
plt.xlabel('time (Day count)')
plt.ylabel('Price (Norm)')
plt.legend(loc='best')
plt.plot();

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, num_feature):
        super(NeuralNetwork, self).__init__()
        self.lstm  = nn.LSTM(num_feature,64,batch_first=True)
        self.fc    = nn.Linear(64,num_feature)  
        
    def forward(self, x):
        output, (hidden, cell) = self.lstm(x)
        x = self.fc(hidden)
        # print(x.shape, hidden.shape, cell.shape, output.shape) 
        # torch.Size([1, 32, 5]) torch.Size([1, 32, 64]) torch.Size([1, 32, 64]) torch.Size([32, 10, 64])
        return x

# %%
model_5d = NeuralNetwork(5)

optimizer = optim.Adam(model_5d.parameters())
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)  # Reduce LR by 10x every 50 epochs

def train(dataloader):
    epoch_loss = 0
    model_5d.train()  
    
    for batch in dataloader:
        optimizer.zero_grad()          
        x,y= batch
        pred = model_5d(x)
        loss = loss = 0.8 * nn.MSELoss()(pred[0], y) + 0.2 * nn.L1Loss()(pred[0], y)      
        loss.backward()               
        optimizer.step()      
        epoch_loss += loss.item()  
        
    return epoch_loss

def evaluate(dataloader):
    epoch_loss = 0
    model_5d.eval()  
    
    with torch.no_grad():
        for batch in dataloader:   
            x,y= batch
            pred = model_5d(x)
            loss = mse(pred[0],y)              
            epoch_loss += loss.item()  
        
    return epoch_loss / len(dataloader)

n_epochs = 100
best_valid_loss_5d = float('inf')

for epoch in range(1, n_epochs + 1 ):

    train_loss_5d = train(train_dataloader_5d)
    valid_loss_5d = evaluate(valid_dataloader_5d)
    
    scheduler.step()
    
    #save the best model
    if valid_loss_5d < best_valid_loss_5d:
        best_valid_loss_5d = valid_loss_5d
        torch.save(model_5d, 'saved_weights_5d.pt')

    # print("Epoch ",epoch+1)
    print(f'\tTrain Loss: {train_loss_5d:.5f} | ' + f'\tVal Loss: {valid_loss_5d:.5f}\n')
    
print("The best model is: ", best_valid_loss_5d)
# Out:
# 	Train Loss: 22.07239 | 	Val Loss: 0.01060
#
# 	Train Loss: 5.52770 | 	Val Loss: 0.00688
#
# 	Train Loss: 4.03053 | 	Val Loss: 0.00503
#
# 	Train Loss: 3.24765 | 	Val Loss: 0.00471
#
# 	Train Loss: 2.84140 | 	Val Loss: 0.00412
#
# 	Train Loss: 2.43633 | 	Val Loss: 0.00342
#
# 	Train Loss: 2.14934 | 	Val Loss: 0.00318
#
# 	Train Loss: 1.93517 | 	Val Loss: 0.00274
#
# 	Train Loss: 1.74452 | 	Val Loss: 0.00255
#
# 	Train Loss: 1.57652 | 	Val Loss: 0.00221
#
# 	Train Loss: 1.40468 | 	Val Loss: 0.00209
#
# 	Train Loss: 1.28666 | 	Val Loss: 0.00201
#
# 	Train Loss: 1.22424 | 	Val Loss: 0.00195
#
# 	Train Loss: 1.18252 | 	Val Loss: 0.00190
#
# 	Train Loss: 1.15285 | 	Val Loss: 0.00184
#
# 	Train Loss: 1.12566 | 	Val Loss: 0.00180
#
# 	Train Loss: 1.10371 | 	Val Loss: 0.00173
#
# 	Train Loss: 1.08240 | 	Val Loss: 0.00169
#
# 	Train Loss: 1.06662 | 	Val Loss: 0.00164
#
# 	Train Loss: 1.04717 | 	Val Loss: 0.00158
#
# 	Train Loss: 1.02820 | 	Val Loss: 0.00155
#
# 	Train Loss: 1.02070 | 	Val Loss: 0.00152
#
# 	Train Loss: 1.00670 | 	Val Loss: 0.00147
#
# 	Train Loss: 0.99564 | 	Val Loss: 0.00144
#
# 	Train Loss: 0.98679 | 	Val Loss: 0.00141
#
# 	Train Loss: 0.96803 | 	Val Loss: 0.00134
#
# 	Train Loss: 0.95119 | 	Val Loss: 0.00134
#
# 	Train Loss: 0.95362 | 	Val Loss: 0.00130
#
# 	Train Loss: 0.94458 | 	Val Loss: 0.00129
#
# 	Train Loss: 0.93210 | 	Val Loss: 0.00121
#
# 	Train Loss: 0.91936 | 	Val Loss: 0.00125
#
# 	Train Loss: 0.91258 | 	Val Loss: 0.00117
#
# 	Train Loss: 0.88912 | 	Val Loss: 0.00116
#
# 	Train Loss: 0.89486 | 	Val Loss: 0.00113
#
# 	Train Loss: 0.88853 | 	Val Loss: 0.00115
#
# 	Train Loss: 0.88310 | 	Val Loss: 0.00107
#
# 	Train Loss: 0.87107 | 	Val Loss: 0.00112
#
# 	Train Loss: 0.88085 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.86246 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.84678 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.83839 | 	Val Loss: 0.00104
#
# 	Train Loss: 0.84798 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.83102 | 	Val Loss: 0.00098
#
# 	Train Loss: 0.82109 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.82148 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.82136 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.79915 | 	Val Loss: 0.00095
#
# 	Train Loss: 0.80896 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.80154 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.79829 | 	Val Loss: 0.00088
#
# 	Train Loss: 1.19466 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.38935 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.36111 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.35824 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.35512 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.35186 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.34974 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.34759 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.34590 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.34416 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.34283 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.34134 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.33987 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.33879 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.33770 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.33641 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.33528 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.33420 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.33317 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.33208 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.33070 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32952 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32814 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32691 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32576 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32490 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32467 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32455 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32445 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.32430 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.32438 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.32380 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.32303 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.32160 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.32149 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.32022 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.32021 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.31890 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.31865 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.31730 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.31632 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.31600 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.31492 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.31409 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.31333 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.31261 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.31174 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.31093 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.31166 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.30939 | 	Val Loss: 0.00019
#
# The best model is:  0.00018956049674064465

# %%
model_5d =torch.load('saved_weights_5d.pt', weights_only=False)

x_test_5d = torch.tensor(x_test_5d).float()

with torch.no_grad():
    y_test_pred_5d = model_5d(x_test_5d)

y_test_pred_5d = y_test_pred_5d.numpy()[0]

idx=0
plt.figure(figsize=(15,5), dpi=200)
plt.plot(np.arange(y_train_5d.shape[0], y_train_5d.shape[0]+y_test_5d.shape[0]),
         y_test_5d[:,idx], color='blue', label='test target')

plt.plot(np.arange(y_train_5d.shape[0], y_train_5d.shape[0]+y_test_pred_5d.shape[0]),
         y_test_pred_5d[:,idx], color='red', label='test prediction')

plt.title('future XRPUSDT prices (With SMA5)')
plt.xlabel('time (Day count)')
plt.ylabel('Price (Norm)')
plt.legend(loc='best')
plt.plot()
# Out:
# /var/folders/7_/0hhqk3r108sg_425jwnnfv1h0000gn/T/ipykernel_59420/3711767162.py:3: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# []

# %%
print(y_test_pred_5d)
y_test_5d
# Out:
# [[0.03581418 0.03570697 0.03736953 0.03667872 0.03636929]
#  [0.03492736 0.03473242 0.03654128 0.03583435 0.03524984]
#  [0.03534892 0.03511576 0.03688216 0.03615585 0.03477098]
#  ...
#  [0.00732767 0.00538797 0.01166857 0.00825354 0.00468538]
#  [0.00712974 0.00518214 0.01149563 0.00806126 0.00454417]
#  [0.00693664 0.00498261 0.01132602 0.00787902 0.0044002 ]]
# array([[0.03421128, 0.03421128, 0.03166562, 0.03268984, 0.03760946],
#        [0.03467876, 0.03605572, 0.03064991, 0.03421128, 0.0363753 ],
#        [0.03008468, 0.03523124, 0.02953645, 0.03467876, 0.03533919],
#        ...,
#        [0.00413935, 0.00444959, 0.0041181 , 0.00444109, 0.00441814],
#        [0.00397786, 0.0042286 , 0.00397786, 0.00413935, 0.00439094],
#        [0.        , 0.00509982, 0.        , 0.00397786, 0.0042881 ]],
#       shape=(359, 5))

# %%
print(model_5d.fc.bias.data)
(y_test_pred_5d - y_test_5d).mean().item()
# Out:
# tensor([0.0970, 0.0895, 0.1022, 0.0918, 0.0767])
# 0.0035545366786073965

# %%
model_9d = NeuralNetwork(5)

optimizer = optim.Adam(model_9d.parameters())

def train(dataloader):
    epoch_loss = 0
    model_9d.train()  
    
    for batch in dataloader:
        optimizer.zero_grad()          
        x,y= batch
        pred = model_9d(x)
        loss = mse(pred[0],y)        
        loss.backward()               
        optimizer.step()      
        epoch_loss += loss.item()  
        
    return epoch_loss

def evaluate(dataloader):
    epoch_loss = 0
    model_9d.eval()  
    
    with torch.no_grad():
        for batch in dataloader:   
            x,y= batch
            pred = model_9d(x)
            loss = mse(pred[0],y)              
            epoch_loss += loss.item()  
        
    return epoch_loss / len(dataloader)

n_epochs = 150
best_valid_loss_9d = float('inf')

for epoch in range(1, n_epochs + 1):

    train_loss_9d = train(train_dataloader_9d)
    valid_loss_9d = evaluate(valid_dataloader_9d)
    
    #save the best model
    if valid_loss_9d < best_valid_loss_9d:
        best_valid_loss_9d = valid_loss_9d
        torch.save(model_9d, 'saved_weights_9d.pt')

    # print("Epoch ",epoch+1)
    print(f'\tTrain Loss: {train_loss_9d:.5f} | ' + f'\tVal Loss: {valid_loss_9d:.5f}\n')
# Out:
# 	Train Loss: 22.29793 | 	Val Loss: 0.01016
#
# 	Train Loss: 4.60397 | 	Val Loss: 0.00458
#
# 	Train Loss: 1.25158 | 	Val Loss: 0.00371
#
# 	Train Loss: 0.81858 | 	Val Loss: 0.00357
#
# 	Train Loss: 0.70701 | 	Val Loss: 0.00355
#
# 	Train Loss: 0.68914 | 	Val Loss: 0.00362
#
# 	Train Loss: 0.74647 | 	Val Loss: 0.00377
#
# 	Train Loss: 0.87701 | 	Val Loss: 0.00387
#
# 	Train Loss: 1.02746 | 	Val Loss: 0.00367
#
# 	Train Loss: 1.05446 | 	Val Loss: 0.00313
#
# 	Train Loss: 0.88670 | 	Val Loss: 0.00249
#
# 	Train Loss: 0.65799 | 	Val Loss: 0.00201
#
# 	Train Loss: 0.49001 | 	Val Loss: 0.00171
#
# 	Train Loss: 0.39324 | 	Val Loss: 0.00153
#
# 	Train Loss: 0.34395 | 	Val Loss: 0.00144
#
# 	Train Loss: 0.32430 | 	Val Loss: 0.00140
#
# 	Train Loss: 0.32522 | 	Val Loss: 0.00141
#
# 	Train Loss: 0.34227 | 	Val Loss: 0.00144
#
# 	Train Loss: 0.37210 | 	Val Loss: 0.00149
#
# 	Train Loss: 0.40958 | 	Val Loss: 0.00154
#
# 	Train Loss: 0.44523 | 	Val Loss: 0.00155
#
# 	Train Loss: 0.46571 | 	Val Loss: 0.00150
#
# 	Train Loss: 0.46119 | 	Val Loss: 0.00141
#
# 	Train Loss: 0.43361 | 	Val Loss: 0.00129
#
# 	Train Loss: 0.39446 | 	Val Loss: 0.00118
#
# 	Train Loss: 0.35549 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.32339 | 	Val Loss: 0.00102
#
# 	Train Loss: 0.30010 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.28512 | 	Val Loss: 0.00095
#
# 	Train Loss: 0.27729 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.27547 | 	Val Loss: 0.00095
#
# 	Train Loss: 0.27865 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.28567 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.29531 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.30587 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.31255 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.31404 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.31126 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.30392 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.29187 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.27966 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.26921 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.25900 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.25105 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.24437 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.24450 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.24628 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.23155 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.19980 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.16758 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.14784 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14014 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14182 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.15216 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.19353 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.27258 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.31800 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.33571 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.38171 | 	Val Loss: 0.00086
#
# 	Train Loss: 0.34628 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.33661 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.27167 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.21319 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.17986 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16367 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.15600 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15313 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15197 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14961 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.14367 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13463 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12572 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.11926 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11570 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.11464 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11542 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11730 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.11958 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12176 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12377 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.12641 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13301 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.15640 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.24930 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.36437 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.39080 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.46557 | 	Val Loss: 0.00111
#
# 	Train Loss: 0.42925 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.27519 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.15705 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11695 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.09967 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.09141 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.08718 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.08513 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.08440 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.08416 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.08476 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.08767 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.09285 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.09857 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.10252 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10365 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10288 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10191 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.10175 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.10273 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.10491 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.10884 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.11869 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.16458 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.31950 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.38540 | 	Val Loss: 0.00104
#
# 	Train Loss: 0.47236 | 	Val Loss: 0.00102
#
# 	Train Loss: 0.41579 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.20415 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.10764 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.08166 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.07232 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.06819 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.06674 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.06810 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07234 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07596 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07717 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07708 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.07642 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.07535 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.07388 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.07227 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07156 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07554 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.09767 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.19787 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.45330 | 	Val Loss: 0.00140
#
# 	Train Loss: 0.62370 | 	Val Loss: 0.00116
#
# 	Train Loss: 0.42082 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.12333 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.07181 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.06482 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.06471 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.06682 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.07070 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.07448 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.07605 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07558 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07436 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07313 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07194 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.07067 | 	Val Loss: 0.00024

# %%
model_9d =torch.load('saved_weights_9d.pt', weights_only=False) 

x_test_9d = torch.tensor(x_test_9d).float()

with torch.no_grad():
    y_test_pred_9d = model_9d(x_test_9d)

y_test_pred_9d = y_test_pred_9d.numpy()[0]

idx=0
plt.figure(figsize=(15,5), dpi=200)
plt.plot(np.arange(y_train_9d.shape[0], y_train_9d.shape[0]+y_test_9d.shape[0]),
         y_test_9d[:,idx], color='blue', label='test target')

plt.plot(np.arange(y_train_9d.shape[0], y_train_9d.shape[0]+y_test_pred_9d.shape[0]),
         y_test_pred_9d[:,idx], color='red', label='test prediction')

plt.title('future XRPUSDT prices (With SMA9)')
plt.xlabel('time (Day count)')
plt.ylabel('Price (Norm)')
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %%
model_20d = NeuralNetwork(5)

optimizer = optim.Adam(model_20d.parameters())

def train(dataloader):
    epoch_loss = 0
    model_20d.train()  
    
    for batch in dataloader:
        optimizer.zero_grad()          
        x,y= batch
        pred = model_20d(x)
        loss = mse(pred[0],y)        
        loss.backward()               
        optimizer.step()      
        epoch_loss += loss.item()  
        
    return epoch_loss

def evaluate(dataloader):
    epoch_loss = 0
    model_20d.eval()  
    
    with torch.no_grad():
        for batch in dataloader:   
            x,y= batch
            pred = model_20d(x)
            loss = mse(pred[0],y)              
            epoch_loss += loss.item()  
        
    return epoch_loss / len(dataloader)

n_epochs = 150
best_valid_loss_20d = float('inf')

for epoch in range(1, n_epochs + 1):

    train_loss_20d = train(train_dataloader_20d)
    valid_loss_20d = evaluate(valid_dataloader_20d)
    
    #save the best model
    if valid_loss_20d < best_valid_loss_20d:
        best_valid_loss_20d = valid_loss_20d
        torch.save(model_20d, 'saved_weights_20d.pt')

    # print("Epoch ",epoch+1)
    print(f'\tTrain Loss: {train_loss_20d:.5f} | ' + f'\tVal Loss: {valid_loss_20d:.5f}\n')
# Out:
# 	Train Loss: 23.89161 | 	Val Loss: 0.01209
#
# 	Train Loss: 6.50490 | 	Val Loss: 0.00437
#
# 	Train Loss: 1.09059 | 	Val Loss: 0.00383
#
# 	Train Loss: 0.77011 | 	Val Loss: 0.00382
#
# 	Train Loss: 0.75159 | 	Val Loss: 0.00403
#
# 	Train Loss: 0.92228 | 	Val Loss: 0.00437
#
# 	Train Loss: 1.31291 | 	Val Loss: 0.00438
#
# 	Train Loss: 1.57723 | 	Val Loss: 0.00346
#
# 	Train Loss: 1.23712 | 	Val Loss: 0.00239
#
# 	Train Loss: 0.78011 | 	Val Loss: 0.00184
#
# 	Train Loss: 0.54585 | 	Val Loss: 0.00158
#
# 	Train Loss: 0.45144 | 	Val Loss: 0.00146
#
# 	Train Loss: 0.42435 | 	Val Loss: 0.00142
#
# 	Train Loss: 0.43371 | 	Val Loss: 0.00143
#
# 	Train Loss: 0.46258 | 	Val Loss: 0.00146
#
# 	Train Loss: 0.48831 | 	Val Loss: 0.00146
#
# 	Train Loss: 0.50419 | 	Val Loss: 0.00145
#
# 	Train Loss: 0.47817 | 	Val Loss: 0.00130
#
# 	Train Loss: 0.50883 | 	Val Loss: 0.00130
#
# 	Train Loss: 0.44835 | 	Val Loss: 0.00120
#
# 	Train Loss: 0.41243 | 	Val Loss: 0.00111
#
# 	Train Loss: 0.37883 | 	Val Loss: 0.00103
#
# 	Train Loss: 0.34810 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.33149 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.32558 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.32520 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.32818 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.33282 | 	Val Loss: 0.00098
#
# 	Train Loss: 0.33148 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.32370 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.24637 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.24303 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.32083 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.21709 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.22831 | 	Val Loss: 0.00080
#
# 	Train Loss: 0.27791 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.33066 | 	Val Loss: 0.00098
#
# 	Train Loss: 0.36854 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.36835 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.33308 | 	Val Loss: 0.00080
#
# 	Train Loss: 0.29010 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.25552 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.23123 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.21884 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.21530 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.21520 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.21986 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.21936 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.21965 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.20985 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.20796 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.19797 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.19141 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.18484 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.18750 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.18592 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.18457 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.18152 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.18423 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.18032 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.18022 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.17514 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.17543 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.17034 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.17208 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.16699 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.16976 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.16397 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.16697 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.16017 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.16370 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.15655 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.16115 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15532 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.15932 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15550 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15562 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.15222 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.15069 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.14864 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.14775 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.14957 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.15166 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.14968 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.14723 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.14561 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.13164 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13127 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15864 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.15548 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.14580 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.13889 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13007 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.12999 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.13428 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.13833 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.14004 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.13394 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.12646 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.12349 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12377 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12542 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.12798 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.12891 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.12995 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12801 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.12132 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.11724 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11698 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.12034 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.12360 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.12392 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.12288 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.12126 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.11875 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11700 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.11463 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.10775 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.10634 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.11197 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11867 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11958 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11136 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.10837 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.11840 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.10942 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.10633 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.10351 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.10351 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10642 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.11032 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.10908 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.10397 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10274 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.10238 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.10417 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.10587 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10936 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.11120 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.10643 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.09966 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.09732 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.10161 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.10281 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.09804 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.10277 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.10458 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.09612 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.09302 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.09349 | 	Val Loss: 0.00028

# %%
model_20d =torch.load('saved_weights_20d.pt', weights_only=False) 

x_test_20d = torch.tensor(x_test_20d).float()

with torch.no_grad():
    y_test_pred_20d = model_20d(x_test_20d)

y_test_pred_20d = y_test_pred_20d.numpy()[0]

idx=0
plt.figure(figsize=(15,5), dpi=200)
plt.plot(np.arange(y_train_20d.shape[0], y_train_20d.shape[0]+y_test_20d.shape[0]),
         y_test_20d[:,idx], color='blue', label='test target')

plt.plot(np.arange(y_train_20d.shape[0], y_train_20d.shape[0]+y_test_pred_20d.shape[0]),
         y_test_pred_20d[:,idx], color='red', label='test prediction')

plt.title('future XRPUSDT prices (With SMA20)')
plt.xlabel('time (Day count)')
plt.ylabel('Price (Norm)')
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %%
model_all = NeuralNetwork(7)

optimizer = optim.Adam(model_all.parameters())

def train(dataloader):
    epoch_loss = 0
    model_all.train()  
    
    for batch in dataloader:
        optimizer.zero_grad()          
        x,y= batch
        pred = model_all(x)
        loss = mse(pred[0],y)        
        loss.backward()               
        optimizer.step()      
        epoch_loss += loss.item()  
        
    return epoch_loss

def evaluate(dataloader):
    epoch_loss = 0
    model_all.eval()  
    
    with torch.no_grad():
        for batch in dataloader:   
            x,y= batch
            pred = model_all(x)
            loss = mse(pred[0],y)              
            epoch_loss += loss.item()  
        
    return epoch_loss / len(dataloader)

n_epochs = 150
best_valid_loss_all = float('inf')

for epoch in range(1, n_epochs + 1):

    train_loss_all = train(train_dataloader_all)
    valid_loss_all = evaluate(valid_dataloader_all)
    
    #save the best model
    if valid_loss_all < best_valid_loss_all:
        best_valid_loss_all = valid_loss_all
        torch.save(model_all, 'saved_weights_all.pt')

    # print("Epoch ",epoch+1)
    print(f'\tTrain Loss: {train_loss_all:.5f} | ' + f'\tVal Loss: {valid_loss_all:.5f}\n')
# Out:
# 	Train Loss: 20.54263 | 	Val Loss: 0.00937
#
# 	Train Loss: 3.90520 | 	Val Loss: 0.00421
#
# 	Train Loss: 1.37119 | 	Val Loss: 0.00347
#
# 	Train Loss: 0.78189 | 	Val Loss: 0.00303
#
# 	Train Loss: 0.61379 | 	Val Loss: 0.00287
#
# 	Train Loss: 0.60080 | 	Val Loss: 0.00292
#
# 	Train Loss: 0.71372 | 	Val Loss: 0.00306
#
# 	Train Loss: 0.92082 | 	Val Loss: 0.00301
#
# 	Train Loss: 1.04272 | 	Val Loss: 0.00252
#
# 	Train Loss: 0.89717 | 	Val Loss: 0.00193
#
# 	Train Loss: 0.65059 | 	Val Loss: 0.00152
#
# 	Train Loss: 0.48377 | 	Val Loss: 0.00130
#
# 	Train Loss: 0.40042 | 	Val Loss: 0.00119
#
# 	Train Loss: 0.36633 | 	Val Loss: 0.00114
#
# 	Train Loss: 0.36099 | 	Val Loss: 0.00113
#
# 	Train Loss: 0.37323 | 	Val Loss: 0.00115
#
# 	Train Loss: 0.39449 | 	Val Loss: 0.00118
#
# 	Train Loss: 0.41536 | 	Val Loss: 0.00119
#
# 	Train Loss: 0.42627 | 	Val Loss: 0.00118
#
# 	Train Loss: 0.42144 | 	Val Loss: 0.00114
#
# 	Train Loss: 0.40196 | 	Val Loss: 0.00107
#
# 	Train Loss: 0.37407 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.34473 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.31895 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.29731 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.26902 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.23112 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.19939 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.18157 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.18187 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.17998 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.20210 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.20400 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.21264 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.23842 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.32298 | 	Val Loss: 0.00141
#
# 	Train Loss: 0.57259 | 	Val Loss: 0.00180
#
# 	Train Loss: 0.68055 | 	Val Loss: 0.00168
#
# 	Train Loss: 0.65814 | 	Val Loss: 0.00115
#
# 	Train Loss: 0.43632 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.29305 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.19834 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14923 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13461 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.14387 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.15334 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.14955 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.14225 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13828 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13592 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13344 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13068 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12817 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12682 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.12813 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13534 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.15688 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.22048 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.42372 | 	Val Loss: 0.00158
#
# 	Train Loss: 0.93594 | 	Val Loss: 0.00297
#
# 	Train Loss: 1.14565 | 	Val Loss: 0.00151
#
# 	Train Loss: 0.70458 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.27404 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.12439 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.09780 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.09801 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11038 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.12333 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.12222 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11639 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11455 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11512 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11546 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11449 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11298 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11236 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11379 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11875 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.13168 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.17111 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.32355 | 	Val Loss: 0.00129
#
# 	Train Loss: 0.68172 | 	Val Loss: 0.00172
#
# 	Train Loss: 0.70708 | 	Val Loss: 0.00105
#
# 	Train Loss: 0.50383 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.26137 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.12780 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.09030 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.09034 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.10759 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.12123 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.11584 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.10816 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.10577 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.10617 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.10601 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.10372 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.10056 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.09858 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.09876 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.10168 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.10964 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.13217 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.21026 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.45285 | 	Val Loss: 0.00136
#
# 	Train Loss: 0.61418 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.37730 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.20947 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.11777 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.09136 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.08037 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.09322 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.10476 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.10100 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.09567 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.09348 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.09155 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.08914 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.08808 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.08848 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.08650 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.08231 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.08514 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.10659 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.13581 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.15475 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.31498 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.47349 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.45033 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.23138 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.10449 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.06476 | 	Val Loss: 0.00020
#
# 	Train Loss: 0.05940 | 	Val Loss: 0.00018
#
# 	Train Loss: 0.06147 | 	Val Loss: 0.00019
#
# 	Train Loss: 0.07073 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.08419 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.09044 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.08735 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.08339 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.08130 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.08009 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.07886 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.07727 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.07540 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.07366 | 	Val Loss: 0.00022
#
# 	Train Loss: 0.07307 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.07628 | 	Val Loss: 0.00021
#
# 	Train Loss: 0.08935 | 	Val Loss: 0.00023
#
# 	Train Loss: 0.12969 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.26373 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.46599 | 	Val Loss: 0.00082

# %%
model_all =torch.load('saved_weights_all.pt', weights_only=False)

x_test_all = torch.tensor(x_test_all).float()

with torch.no_grad():
    y_test_pred_all = model_all(x_test_all)

y_test_pred_all = y_test_pred_all.numpy()[0]

idx=0
plt.figure(figsize=(15,5), dpi=200)
plt.plot(np.arange(y_train_all.shape[0], y_train_all.shape[0]+y_test_all.shape[0]),
         y_test_all[:,idx], color='blue', label='test target')

plt.plot(np.arange(y_train_all.shape[0], y_train_all.shape[0]+y_test_pred_all.shape[0]),
         y_test_pred_all[:,idx], color='red', label='test prediction')

plt.title('future XRPUSDT prices (With SMA (5,9,17))')
plt.xlabel('time (Day count)')
plt.ylabel('Price (Norm)')
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %%
idx=0
plt.figure(figsize=(15,5), dpi=200)
plt.plot(np.arange(y_train_5d.shape[0], y_train_5d.shape[0]+y_test_5d.shape[0]),
         y_test_5d[:,idx], color='#4000D5', label='test target')

plt.plot(np.arange(y_train_5d.shape[0], y_train_5d.shape[0]+y_test_pred_5d.shape[0]),
         y_test_pred_5d[:,idx], color='#A700D5', label='test prediction (SMA5)')

plt.plot(np.arange(y_train_9d.shape[0], y_train_9d.shape[0]+y_test_pred_9d.shape[0]),
         y_test_pred_9d[:,idx], color='#D20103', label='test prediction (SMA9)')

plt.plot(np.arange(y_train_20d.shape[0], y_train_20d.shape[0]+y_test_pred_20d.shape[0]),
         y_test_pred_20d[:,idx], color='#00D5D2', label='test prediction (SMA20)')

plt.plot(np.arange(y_train_all.shape[0], y_train_all.shape[0]+y_test_pred_all.shape[0]),
         y_test_pred_all[:,idx], color='#40D500', label='test prediction (All)')



plt.title('future XRPUSDT prices (With all SMAs)')
plt.xlabel('time (Day count)')
plt.ylabel('Price (Norm)')
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %%
sma_window = 14

# %%
for sma_window in range(5,15):    
    df[f"{sma_window}d_sma"] = df["Close"].rolling(sma_window).mean()
    df[f"{sma_window}d_sma"] = df[f"{sma_window}d_sma"].fillna(df['Close'])
    _d = df[['Open','High','Low','Days', f'{sma_window}d_sma','Volume','Close']].copy(deep=True)

    scaler = MinMaxScaler(feature_range=(0,2)).fit(_d.Low.values.reshape(-1,1))

    _d['Open'] = scaler.transform(_d.Open.values.reshape(-1,1))
    _d['High'] = scaler.transform(_d.High.values.reshape(-1,1))
    _d['Low'] = scaler.transform(_d.Low.values.reshape(-1,1))
    _d['Close'] = scaler.transform(_d.Close.values.reshape(-1,1))
    _d['Volume'] = scaler.transform(_d.Volume.values.reshape(-1,1))
    _d['Days'] = scaler.transform(_d.Days.values.reshape(-1,1))
    _d[f'{sma_window}d_sma'] = scaler.transform(_d[f'{sma_window}d_sma'].values.reshape(-1,1))

    data_nd = _d[['Open','High','Low', f'{sma_window}d_sma','Close']].values

    sequences_nd=[]
    for index in range(len(data_nd) - seq_len + 1):
        sequences_nd.append(data_nd[index: index + seq_len])
    sequences_nd = np.array(sequences_nd)
    print(sequences_nd.shape)

    valid_set_size_nd = int(np.round(valid_set_size_percentage/100*sequences_nd.shape[0]))
    test_set_size_nd  = int(np.round(test_set_size_percentage/100*sequences_nd.shape[0]))
    train_set_size_nd = sequences_nd.shape[0] - (valid_set_size_nd + test_set_size_nd)

    x_train_nd = sequences_nd[:train_set_size_nd,:-1,:]
    y_train_nd = sequences_nd[:train_set_size_nd,-1,:]

    x_valid_nd = sequences_nd[train_set_size_nd:train_set_size_nd+valid_set_size_nd,:-1,:]
    y_valid_nd = sequences_nd[train_set_size_nd:train_set_size_nd+valid_set_size_nd,-1,:]

    x_test_nd = sequences_nd[train_set_size_nd+valid_set_size_nd:,:-1,:]
    y_test_nd = sequences_nd[train_set_size_nd+valid_set_size_nd:,-1,:]

    x_train_nd = torch.tensor(x_train_nd).float()
    y_train_nd = torch.tensor(y_train_nd).float()

    x_valid_nd = torch.tensor(x_valid_nd).float()
    y_valid_nd = torch.tensor(y_valid_nd).float()

    train_dataset_nd = TensorDataset(x_train_nd,y_train_nd)
    train_dataloader_nd = DataLoader(train_dataset_nd, batch_size=32, shuffle=False)

    valid_dataset_nd = TensorDataset(x_valid_nd,y_valid_nd)
    valid_dataloader_nd = DataLoader(valid_dataset_nd, batch_size=32, shuffle=False)

    model_nd = NeuralNetwork(5)

    optimizer = optim.Adam(model_nd.parameters())

    def train(dataloader):
        epoch_loss = 0
        model_nd.train()

        for batch in dataloader:
            optimizer.zero_grad()          
            x,y= batch
            pred = model_nd(x)
            loss = mse(pred[0],y)        
            loss.backward()               
            optimizer.step()      
            epoch_loss += loss.item()  
            
        return epoch_loss

    def evaluate(dataloader):
        epoch_loss = 0
        model_nd.eval()

        with torch.no_grad():
            for batch in dataloader:   
                x,y= batch
                pred = model_nd(x)
                loss = mse(pred[0],y)              
                epoch_loss += loss.item()  
            
        return epoch_loss / len(dataloader)

    n_epochs = 150
    best_valid_loss_nd = float('inf')

    for epoch in range(1, n_epochs + 1):

        train_loss_nd = train(train_dataloader_nd)
        valid_loss_nd = evaluate(valid_dataloader_nd)

        #save the best model
        if valid_loss_nd < best_valid_loss_nd:
            best_valid_loss_nd = valid_loss_nd
            torch.save(model_nd, 'saved_weights_nd.pt')

        # print("Epoch ",epoch+1)
        print(f'\tTrain Loss: {train_loss_nd:.5f} | ' + f'\tVal Loss: {valid_loss_nd:.5f}\n')

    model_nd =torch.load('saved_weights_nd.pt', weights_only=False)

    x_test_nd = torch.tensor(x_test_nd).float()

    with torch.no_grad():
        y_test_pred_nd = model_nd(x_test_nd)

    y_test_pred_nd = y_test_pred_nd.numpy()[0]

    # idx=0
    # plt.figure(figsize=(15,5), dpi=200)
    # plt.plot(np.arange(y_train_nd.shape[0], y_train_nd.shape[0]+y_test_nd.shape[0]),
    # y_test_nd[:,idx], color='blue', label='test target')

    # plt.plot(np.arange(y_train_nd.shape[0], y_train_nd.shape[0]+y_test_pred_nd.shape[0]),
    # y_test_pred_nd[:,idx], color='red', label='test prediction')

    # plt.title('future XRPUSDT prices (With SMAn)')
    # plt.xlabel('time (Day count)')
    # plt.ylabel('Price (Norm)')
    # plt.legend(loc='best')
    # plt.plot()


    ress[sma_window] = y_test_pred_nd[:,0]
# Out:
# (3590, 11, 5)
# 	Train Loss: 23.14995 | 	Val Loss: 0.00941
#
# 	Train Loss: 7.04837 | 	Val Loss: 0.00359
#
# 	Train Loss: 0.87097 | 	Val Loss: 0.00332
#
# 	Train Loss: 0.51189 | 	Val Loss: 0.00278
#
# 	Train Loss: 0.37460 | 	Val Loss: 0.00250
#
# 	Train Loss: 0.32664 | 	Val Loss: 0.00246
#
# 	Train Loss: 0.35145 | 	Val Loss: 0.00269
#
# 	Train Loss: 0.57772 | 	Val Loss: 0.00355
#
# 	Train Loss: 1.38166 | 	Val Loss: 0.00433
#
# 	Train Loss: 2.40240 | 	Val Loss: 0.00262
#
# 	Train Loss: 1.37390 | 	Val Loss: 0.00155
#
# 	Train Loss: 0.54003 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.30613 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.24029 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.22482 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.23560 | 	Val Loss: 0.00081
#
# 	Train Loss: 0.26905 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.32392 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.39052 | 	Val Loss: 0.00105
#
# 	Train Loss: 0.44510 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.46122 | 	Val Loss: 0.00104
#
# 	Train Loss: 0.43482 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.38717 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.34103 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.30670 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.28518 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.27418 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.27104 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.27334 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.27884 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.28534 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.29083 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.29374 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.29332 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.28973 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.28385 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.27683 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.26975 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.26339 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.25816 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.25415 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.25123 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.24916 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.24759 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.24623 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.24482 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.24323 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.24157 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.24161 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.24277 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.23630 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.23253 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.22778 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.22186 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.21712 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.21270 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.20928 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.20725 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.20472 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.20592 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.21415 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.21236 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.21363 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.20426 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.17450 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.19881 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.20381 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.20306 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.19071 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.18931 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.19407 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.19244 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.18792 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.18727 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.18885 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.19008 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.19127 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.19300 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.18069 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.17918 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.18475 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.17872 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.17065 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15208 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.16377 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.16970 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.17046 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.16248 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.16912 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.17618 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.17879 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.16703 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.16362 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.17532 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.17245 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.16027 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15494 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.15903 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.15844 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.15045 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.14770 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15709 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15562 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.15610 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.13747 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.16015 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.15832 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.16247 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.14677 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.15249 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.15170 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.14454 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.13656 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.14362 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.14211 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.14132 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12946 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.14858 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.14432 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.14924 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13241 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.14596 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.14398 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.14187 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.13211 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.13735 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13067 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.12839 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.12271 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13397 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12750 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12997 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.12059 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13616 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13211 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.13107 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.13409 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.14325 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.13351 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.12608 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.12096 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12348 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.11805 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11618 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.11143 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.12390 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.12028 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.12514 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11369 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.12544 | 	Val Loss: 0.00033
#
# (3590, 11, 5)
# 	Train Loss: 20.74587 | 	Val Loss: 0.01116
#
# 	Train Loss: 5.46561 | 	Val Loss: 0.00526
#
# 	Train Loss: 1.56993 | 	Val Loss: 0.00397
#
# 	Train Loss: 0.84300 | 	Val Loss: 0.00346
#
# 	Train Loss: 0.61611 | 	Val Loss: 0.00318
#
# 	Train Loss: 0.55026 | 	Val Loss: 0.00310
#
# 	Train Loss: 0.59434 | 	Val Loss: 0.00323
#
# 	Train Loss: 0.75997 | 	Val Loss: 0.00344
#
# 	Train Loss: 1.02456 | 	Val Loss: 0.00339
#
# 	Train Loss: 1.17644 | 	Val Loss: 0.00285
#
# 	Train Loss: 0.99403 | 	Val Loss: 0.00216
#
# 	Train Loss: 0.68996 | 	Val Loss: 0.00168
#
# 	Train Loss: 0.48680 | 	Val Loss: 0.00142
#
# 	Train Loss: 0.38522 | 	Val Loss: 0.00129
#
# 	Train Loss: 0.34076 | 	Val Loss: 0.00122
#
# 	Train Loss: 0.32773 | 	Val Loss: 0.00120
#
# 	Train Loss: 0.33371 | 	Val Loss: 0.00121
#
# 	Train Loss: 0.35117 | 	Val Loss: 0.00124
#
# 	Train Loss: 0.37315 | 	Val Loss: 0.00126
#
# 	Train Loss: 0.39211 | 	Val Loss: 0.00126
#
# 	Train Loss: 0.40114 | 	Val Loss: 0.00123
#
# 	Train Loss: 0.39729 | 	Val Loss: 0.00119
#
# 	Train Loss: 0.38304 | 	Val Loss: 0.00112
#
# 	Train Loss: 0.36271 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.34173 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.32383 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.31043 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.30133 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.29555 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.29250 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.29194 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.29334 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.29510 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.29506 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.29123 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.28386 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.27699 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.27887 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.28622 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.28781 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.28952 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.25041 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.19031 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.19862 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.25081 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.27853 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.28518 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.25793 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.22744 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.23539 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.24556 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.24188 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.22645 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.22563 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.20212 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.19219 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.21000 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.23517 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.24640 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.22561 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.19541 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.20702 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.22811 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.23038 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.22461 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.17356 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.16826 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.19690 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.21165 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.21159 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.18930 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.18613 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.19367 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.19669 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.18722 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.17654 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.18151 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.19936 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.20391 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.19822 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14781 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.15086 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.19209 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.19486 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.19036 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.16508 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.17410 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.17776 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17229 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15315 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.15531 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.17108 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.17724 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.17065 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14333 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.16424 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17963 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.18134 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15699 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.14558 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.16473 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.16480 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.15206 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13748 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.15056 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15623 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.15654 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13622 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13940 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.16313 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16076 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.16343 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.14024 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.15900 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15756 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.14965 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12624 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13009 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13946 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13910 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13268 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12710 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.14300 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.15163 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15306 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13532 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13412 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.15135 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.14369 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13727 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12207 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13110 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13477 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13365 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12167 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12433 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.13782 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13292 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13367 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12205 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13183 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13557 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13415 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.12157 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.12270 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.13317 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12774 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12377 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.11423 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.12339 | 	Val Loss: 0.00040
#
# (3590, 11, 5)
# 	Train Loss: 23.73138 | 	Val Loss: 0.01155
#
# 	Train Loss: 5.46339 | 	Val Loss: 0.00486
#
# 	Train Loss: 1.43678 | 	Val Loss: 0.00391
#
# 	Train Loss: 0.80345 | 	Val Loss: 0.00341
#
# 	Train Loss: 0.61384 | 	Val Loss: 0.00326
#
# 	Train Loss: 0.55329 | 	Val Loss: 0.00332
#
# 	Train Loss: 0.58832 | 	Val Loss: 0.00358
#
# 	Train Loss: 0.74725 | 	Val Loss: 0.00395
#
# 	Train Loss: 1.02996 | 	Val Loss: 0.00401
#
# 	Train Loss: 1.20342 | 	Val Loss: 0.00333
#
# 	Train Loss: 0.99075 | 	Val Loss: 0.00243
#
# 	Train Loss: 0.65764 | 	Val Loss: 0.00185
#
# 	Train Loss: 0.45366 | 	Val Loss: 0.00156
#
# 	Train Loss: 0.35862 | 	Val Loss: 0.00142
#
# 	Train Loss: 0.32105 | 	Val Loss: 0.00136
#
# 	Train Loss: 0.31657 | 	Val Loss: 0.00136
#
# 	Train Loss: 0.33568 | 	Val Loss: 0.00140
#
# 	Train Loss: 0.37208 | 	Val Loss: 0.00146
#
# 	Train Loss: 0.41518 | 	Val Loss: 0.00150
#
# 	Train Loss: 0.44829 | 	Val Loss: 0.00149
#
# 	Train Loss: 0.45631 | 	Val Loss: 0.00142
#
# 	Train Loss: 0.43710 | 	Val Loss: 0.00131
#
# 	Train Loss: 0.40220 | 	Val Loss: 0.00121
#
# 	Train Loss: 0.36583 | 	Val Loss: 0.00112
#
# 	Train Loss: 0.33640 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.31635 | 	Val Loss: 0.00102
#
# 	Train Loss: 0.30500 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.30062 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.30117 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.30457 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.30867 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.31157 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.31198 | 	Val Loss: 0.00098
#
# 	Train Loss: 0.30943 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.30430 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.29753 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.29023 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.28334 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.27746 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.27280 | 	Val Loss: 0.00086
#
# 	Train Loss: 0.26936 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.26691 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.26504 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.26324 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.26125 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.25914 | 	Val Loss: 0.00081
#
# 	Train Loss: 0.25683 | 	Val Loss: 0.00080
#
# 	Train Loss: 0.25364 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.24897 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.24399 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.24244 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.24494 | 	Val Loss: 0.00078
#
# 	Train Loss: 0.24444 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.23575 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.20487 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.17494 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.22627 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.25546 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.26950 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.22035 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.21443 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.23286 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.22710 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.19661 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.19715 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.21223 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.21727 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.19134 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.18114 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.21529 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.22853 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.21074 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.17156 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.20505 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.21545 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.19189 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.16497 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.18516 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.19427 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.17957 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.15559 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.18668 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.19952 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.19238 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.15326 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.18632 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.19523 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.18414 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15326 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17457 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.17882 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.16211 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13445 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.15878 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.17018 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.17918 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.14432 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.16693 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.17968 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.18036 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14037 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14764 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15663 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.15557 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.12848 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12586 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.15052 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.16379 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.16801 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13477 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.15049 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.17069 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.17214 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.13915 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13119 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.15275 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14965 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.13987 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11136 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.11701 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.14036 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14899 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14830 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.12774 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.14618 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.16416 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.16122 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13522 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12711 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14039 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13291 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.12350 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.10049 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10801 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13216 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14008 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.14327 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12462 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.14323 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14977 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.14358 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.12373 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13016 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13191 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12395 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.10469 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.09784 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.11623 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12336 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13144 | 	Val Loss: 0.00035
#
# (3590, 11, 5)
# 	Train Loss: 25.97092 | 	Val Loss: 0.01162
#
# 	Train Loss: 5.12483 | 	Val Loss: 0.00596
#
# 	Train Loss: 2.21142 | 	Val Loss: 0.00431
#
# 	Train Loss: 1.16147 | 	Val Loss: 0.00361
#
# 	Train Loss: 0.82768 | 	Val Loss: 0.00330
#
# 	Train Loss: 0.69687 | 	Val Loss: 0.00318
#
# 	Train Loss: 0.66277 | 	Val Loss: 0.00321
#
# 	Train Loss: 0.70162 | 	Val Loss: 0.00332
#
# 	Train Loss: 0.79931 | 	Val Loss: 0.00342
#
# 	Train Loss: 0.90462 | 	Val Loss: 0.00330
#
# 	Train Loss: 0.91750 | 	Val Loss: 0.00290
#
# 	Train Loss: 0.79493 | 	Val Loss: 0.00239
#
# 	Train Loss: 0.62230 | 	Val Loss: 0.00197
#
# 	Train Loss: 0.48701 | 	Val Loss: 0.00169
#
# 	Train Loss: 0.40614 | 	Val Loss: 0.00154
#
# 	Train Loss: 0.36624 | 	Val Loss: 0.00147
#
# 	Train Loss: 0.35398 | 	Val Loss: 0.00145
#
# 	Train Loss: 0.36108 | 	Val Loss: 0.00147
#
# 	Train Loss: 0.38139 | 	Val Loss: 0.00151
#
# 	Train Loss: 0.40784 | 	Val Loss: 0.00154
#
# 	Train Loss: 0.43108 | 	Val Loss: 0.00154
#
# 	Train Loss: 0.44165 | 	Val Loss: 0.00149
#
# 	Train Loss: 0.43482 | 	Val Loss: 0.00141
#
# 	Train Loss: 0.41356 | 	Val Loss: 0.00132
#
# 	Train Loss: 0.38572 | 	Val Loss: 0.00123
#
# 	Train Loss: 0.35882 | 	Val Loss: 0.00115
#
# 	Train Loss: 0.33724 | 	Val Loss: 0.00110
#
# 	Train Loss: 0.32239 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.31393 | 	Val Loss: 0.00104
#
# 	Train Loss: 0.31076 | 	Val Loss: 0.00103
#
# 	Train Loss: 0.31145 | 	Val Loss: 0.00103
#
# 	Train Loss: 0.31443 | 	Val Loss: 0.00103
#
# 	Train Loss: 0.31808 | 	Val Loss: 0.00103
#
# 	Train Loss: 0.32067 | 	Val Loss: 0.00103
#
# 	Train Loss: 0.32088 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.31817 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.31284 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.30643 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.29947 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.29148 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.28256 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.28504 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.27948 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.26737 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.26003 | 	Val Loss: 0.00081
#
# 	Train Loss: 0.26136 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.27364 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.26514 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.24256 | 	Val Loss: 0.00078
#
# 	Train Loss: 0.25773 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.27097 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.26638 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.24144 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.24358 | 	Val Loss: 0.00078
#
# 	Train Loss: 0.25001 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.24178 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.21642 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.22748 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.23585 | 	Val Loss: 0.00080
#
# 	Train Loss: 0.25316 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.20481 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.22345 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.23378 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.24570 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.21192 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.21137 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.21594 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.22019 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.18781 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.18970 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.20588 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.22399 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.20318 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.18590 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.20760 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.21723 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.20074 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17682 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.19167 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.19897 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.19438 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15628 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.18602 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.19077 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.20948 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.16577 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.18420 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.18924 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.19472 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.15962 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.17369 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.17699 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.18720 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.14972 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.16863 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17148 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.18541 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.15384 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16672 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17047 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.17468 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.14944 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.16131 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.16210 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.16819 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13877 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.15378 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.15300 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.16863 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14026 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.15084 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.15263 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.16541 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.14199 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13921 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.14841 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15303 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14864 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12603 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.14475 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.14625 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15984 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13664 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.13741 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.14537 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.14871 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13876 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11769 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13351 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13674 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14696 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13062 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12141 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13786 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13935 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14646 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.11914 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12513 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13412 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13830 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13156 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.11311 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12491 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12778 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13572 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.11911 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.11082 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12479 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12785 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13696 | 	Val Loss: 0.00035
#
# (3590, 11, 5)
# 	Train Loss: 20.30068 | 	Val Loss: 0.00826
#
# 	Train Loss: 4.20553 | 	Val Loss: 0.00434
#
# 	Train Loss: 1.57397 | 	Val Loss: 0.00374
#
# 	Train Loss: 1.02641 | 	Val Loss: 0.00343
#
# 	Train Loss: 0.85878 | 	Val Loss: 0.00331
#
# 	Train Loss: 0.81890 | 	Val Loss: 0.00325
#
# 	Train Loss: 0.84444 | 	Val Loss: 0.00318
#
# 	Train Loss: 0.88637 | 	Val Loss: 0.00300
#
# 	Train Loss: 0.88185 | 	Val Loss: 0.00269
#
# 	Train Loss: 0.80021 | 	Val Loss: 0.00231
#
# 	Train Loss: 0.67742 | 	Val Loss: 0.00197
#
# 	Train Loss: 0.56663 | 	Val Loss: 0.00172
#
# 	Train Loss: 0.49006 | 	Val Loss: 0.00155
#
# 	Train Loss: 0.44560 | 	Val Loss: 0.00144
#
# 	Train Loss: 0.42097 | 	Val Loss: 0.00139
#
# 	Train Loss: 0.42246 | 	Val Loss: 0.00134
#
# 	Train Loss: 0.42252 | 	Val Loss: 0.00129
#
# 	Train Loss: 0.42289 | 	Val Loss: 0.00127
#
# 	Train Loss: 0.42476 | 	Val Loss: 0.00120
#
# 	Train Loss: 0.42585 | 	Val Loss: 0.00119
#
# 	Train Loss: 0.43106 | 	Val Loss: 0.00114
#
# 	Train Loss: 0.40730 | 	Val Loss: 0.00105
#
# 	Train Loss: 0.37340 | 	Val Loss: 0.00098
#
# 	Train Loss: 0.34946 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.32639 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.30809 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.29849 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.29489 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.29318 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.29280 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.29870 | 	Val Loss: 0.00086
#
# 	Train Loss: 0.31507 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.33082 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.33814 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.32855 | 	Val Loss: 0.00081
#
# 	Train Loss: 0.30912 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.24378 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.18309 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16807 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.20048 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.26629 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.32391 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.35523 | 	Val Loss: 0.00086
#
# 	Train Loss: 0.31766 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.29031 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.28666 | 	Val Loss: 0.00078
#
# 	Train Loss: 0.28854 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.25015 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.19982 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.19656 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.21696 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.23543 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.25396 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.23718 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.18222 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.15893 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.19356 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.25394 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.27637 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.29456 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.21981 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.22059 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.23582 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.23441 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.21100 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.16833 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.15850 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.18303 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.21413 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.22676 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.24099 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.17927 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.12870 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.15222 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.21825 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.23011 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.24941 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.18687 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.17219 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.19737 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.20456 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.19811 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.16336 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.13299 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13466 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.17213 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.20200 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.21436 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.22143 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.13904 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.14988 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.18827 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.18983 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.18710 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.13598 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12359 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.15540 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.17705 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.17874 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.17891 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12653 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.14392 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.18113 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.18132 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.17907 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.12696 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.14243 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.16194 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.16262 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.15469 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.11421 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11869 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.15514 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.15876 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.17266 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.14545 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.12866 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.16027 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.15895 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.16104 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12433 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11851 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.14541 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.14460 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.15060 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12386 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11099 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.13892 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.14888 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.15096 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.13859 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11617 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.14045 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.14654 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.14719 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.12700 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.10685 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.12569 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.13713 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.13399 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13220 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.10934 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.12103 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.14046 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.13326 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.13630 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.11173 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.11641 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.13690 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12941 | 	Val Loss: 0.00033
#
# (3590, 11, 5)
# 	Train Loss: 30.40578 | 	Val Loss: 0.01578
#
# 	Train Loss: 9.54204 | 	Val Loss: 0.00302
#
# 	Train Loss: 0.80662 | 	Val Loss: 0.00313
#
# 	Train Loss: 0.51520 | 	Val Loss: 0.00279
#
# 	Train Loss: 0.39601 | 	Val Loss: 0.00269
#
# 	Train Loss: 0.34558 | 	Val Loss: 0.00274
#
# 	Train Loss: 0.34538 | 	Val Loss: 0.00310
#
# 	Train Loss: 0.48780 | 	Val Loss: 0.00426
#
# 	Train Loss: 1.14644 | 	Val Loss: 0.00630
#
# 	Train Loss: 2.45055 | 	Val Loss: 0.00484
#
# 	Train Loss: 1.67999 | 	Val Loss: 0.00217
#
# 	Train Loss: 0.59307 | 	Val Loss: 0.00140
#
# 	Train Loss: 0.32483 | 	Val Loss: 0.00120
#
# 	Train Loss: 0.25824 | 	Val Loss: 0.00112
#
# 	Train Loss: 0.24501 | 	Val Loss: 0.00111
#
# 	Train Loss: 0.26157 | 	Val Loss: 0.00116
#
# 	Train Loss: 0.30613 | 	Val Loss: 0.00128
#
# 	Train Loss: 0.37526 | 	Val Loss: 0.00142
#
# 	Train Loss: 0.44817 | 	Val Loss: 0.00151
#
# 	Train Loss: 0.48804 | 	Val Loss: 0.00148
#
# 	Train Loss: 0.47596 | 	Val Loss: 0.00137
#
# 	Train Loss: 0.43070 | 	Val Loss: 0.00124
#
# 	Train Loss: 0.38094 | 	Val Loss: 0.00114
#
# 	Train Loss: 0.34205 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.31711 | 	Val Loss: 0.00102
#
# 	Train Loss: 0.30411 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.29987 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.30115 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.30484 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.30816 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.30915 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.30715 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.30276 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.29705 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.29042 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.28258 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.27309 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.26166 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.25126 | 	Val Loss: 0.00086
#
# 	Train Loss: 0.26075 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.29839 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.27982 | 	Val Loss: 0.00101
#
# 	Train Loss: 0.30824 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.23111 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.23259 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.25973 | 	Val Loss: 0.00095
#
# 	Train Loss: 0.26708 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.24868 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.23773 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.24556 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.24997 | 	Val Loss: 0.00086
#
# 	Train Loss: 0.23896 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.20588 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.21602 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.24844 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.25828 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.24554 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.20114 | 	Val Loss: 0.00080
#
# 	Train Loss: 0.22799 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.23498 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.22273 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.18701 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.20637 | 	Val Loss: 0.00078
#
# 	Train Loss: 0.21598 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.23017 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.17837 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.18713 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.22095 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.23367 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.20512 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.18732 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.20598 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.20967 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.18668 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.15741 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.19268 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.19227 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.21332 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.15234 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.18409 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.19887 | 	Val Loss: 0.00078
#
# 	Train Loss: 0.21194 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.16797 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.17883 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.18315 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.19592 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.15303 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.15101 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.17706 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.18614 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.17148 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15320 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.17666 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.18205 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.16939 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15212 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.16830 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.17276 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.15778 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14356 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.15985 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.16592 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.15485 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.14322 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.15854 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.16574 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.15170 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.14483 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.15327 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.16043 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.14114 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13569 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.14466 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.15176 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.14014 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13131 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.14538 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.15035 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.14507 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13310 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.14567 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.14665 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.13742 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12251 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13562 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.13399 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.13650 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.11681 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13118 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13259 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.13968 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.12114 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12289 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13403 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.13384 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13260 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11499 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12976 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.12906 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13247 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.11504 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.11436 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12615 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.12315 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13096 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.10863 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.11867 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.12771 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13279 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12332 | 	Val Loss: 0.00034
#
# (3590, 11, 5)
# 	Train Loss: 23.48362 | 	Val Loss: 0.01096
#
# 	Train Loss: 5.82952 | 	Val Loss: 0.00412
#
# 	Train Loss: 1.21724 | 	Val Loss: 0.00362
#
# 	Train Loss: 0.74476 | 	Val Loss: 0.00330
#
# 	Train Loss: 0.60874 | 	Val Loss: 0.00324
#
# 	Train Loss: 0.59089 | 	Val Loss: 0.00337
#
# 	Train Loss: 0.70483 | 	Val Loss: 0.00373
#
# 	Train Loss: 1.02221 | 	Val Loss: 0.00404
#
# 	Train Loss: 1.43352 | 	Val Loss: 0.00354
#
# 	Train Loss: 1.35038 | 	Val Loss: 0.00248
#
# 	Train Loss: 0.86480 | 	Val Loss: 0.00178
#
# 	Train Loss: 0.54586 | 	Val Loss: 0.00146
#
# 	Train Loss: 0.40725 | 	Val Loss: 0.00131
#
# 	Train Loss: 0.35296 | 	Val Loss: 0.00124
#
# 	Train Loss: 0.33941 | 	Val Loss: 0.00123
#
# 	Train Loss: 0.35047 | 	Val Loss: 0.00126
#
# 	Train Loss: 0.37832 | 	Val Loss: 0.00132
#
# 	Train Loss: 0.41484 | 	Val Loss: 0.00137
#
# 	Train Loss: 0.44711 | 	Val Loss: 0.00139
#
# 	Train Loss: 0.46524 | 	Val Loss: 0.00135
#
# 	Train Loss: 0.46247 | 	Val Loss: 0.00127
#
# 	Train Loss: 0.43235 | 	Val Loss: 0.00118
#
# 	Train Loss: 0.39642 | 	Val Loss: 0.00110
#
# 	Train Loss: 0.36372 | 	Val Loss: 0.00103
#
# 	Train Loss: 0.33834 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.32224 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.31582 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.31050 | 	Val Loss: 0.00094
#
# 	Train Loss: 0.31144 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.30788 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.30996 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.30869 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.30051 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.24840 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.20634 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.20357 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.24124 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.27645 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.32109 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.35048 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.34071 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.32919 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.31589 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.30711 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.24135 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.24003 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.23251 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.24559 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.22065 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.19815 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.22595 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.23099 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.25351 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.26159 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.21734 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.24922 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.24606 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.26821 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.22440 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.22160 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.22274 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.22352 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.22626 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.16419 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.18563 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.20640 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.21763 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.23253 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.18134 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.20285 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.20692 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.22986 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.20713 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.17752 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.19658 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.19039 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.21059 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.16897 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15871 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.18174 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.17875 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.20030 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.16759 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16866 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.18690 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.18416 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.19928 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.15844 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.17721 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.17488 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.18614 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.17172 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.15605 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.17257 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.16178 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.17831 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14951 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.14980 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.16615 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.15948 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17661 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.14625 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.16081 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.16305 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.16353 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16415 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13994 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.16117 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15014 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.16038 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.14581 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13465 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.15565 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.14493 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.15886 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13924 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13783 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.15389 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14238 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.15608 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13209 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13980 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14713 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13732 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.14775 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12348 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.13302 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13959 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13008 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.14188 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12073 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.12501 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13975 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.12935 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.14083 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12579 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.12301 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13722 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.12542 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13129 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12356 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.10873 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.12427 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12837 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.11945 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13040 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.11413 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10858 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.12586 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12361 | 	Val Loss: 0.00037
#
# (3590, 11, 5)
# 	Train Loss: 25.37423 | 	Val Loss: 0.01319
#
# 	Train Loss: 6.02156 | 	Val Loss: 0.00503
#
# 	Train Loss: 1.53526 | 	Val Loss: 0.00399
#
# 	Train Loss: 1.01425 | 	Val Loss: 0.00387
#
# 	Train Loss: 0.93861 | 	Val Loss: 0.00395
#
# 	Train Loss: 0.99815 | 	Val Loss: 0.00403
#
# 	Train Loss: 1.10039 | 	Val Loss: 0.00389
#
# 	Train Loss: 1.11598 | 	Val Loss: 0.00342
#
# 	Train Loss: 0.97248 | 	Val Loss: 0.00281
#
# 	Train Loss: 0.76285 | 	Val Loss: 0.00231
#
# 	Train Loss: 0.59672 | 	Val Loss: 0.00199
#
# 	Train Loss: 0.49787 | 	Val Loss: 0.00180
#
# 	Train Loss: 0.45047 | 	Val Loss: 0.00171
#
# 	Train Loss: 0.43769 | 	Val Loss: 0.00168
#
# 	Train Loss: 0.44776 | 	Val Loss: 0.00168
#
# 	Train Loss: 0.47032 | 	Val Loss: 0.00170
#
# 	Train Loss: 0.49324 | 	Val Loss: 0.00169
#
# 	Train Loss: 0.50372 | 	Val Loss: 0.00163
#
# 	Train Loss: 0.49909 | 	Val Loss: 0.00154
#
# 	Train Loss: 0.47323 | 	Val Loss: 0.00141
#
# 	Train Loss: 0.43643 | 	Val Loss: 0.00131
#
# 	Train Loss: 0.40316 | 	Val Loss: 0.00122
#
# 	Train Loss: 0.37589 | 	Val Loss: 0.00116
#
# 	Train Loss: 0.35778 | 	Val Loss: 0.00112
#
# 	Train Loss: 0.34677 | 	Val Loss: 0.00110
#
# 	Train Loss: 0.34245 | 	Val Loss: 0.00110
#
# 	Train Loss: 0.34246 | 	Val Loss: 0.00110
#
# 	Train Loss: 0.34460 | 	Val Loss: 0.00110
#
# 	Train Loss: 0.35114 | 	Val Loss: 0.00109
#
# 	Train Loss: 0.35477 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.35520 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.34665 | 	Val Loss: 0.00102
#
# 	Train Loss: 0.33405 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.31949 | 	Val Loss: 0.00097
#
# 	Train Loss: 0.30806 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.29348 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.28407 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.30200 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.34309 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.23816 | 	Val Loss: 0.00065
#
# 	Train Loss: 0.20488 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.24930 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.29243 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.32139 | 	Val Loss: 0.00098
#
# 	Train Loss: 0.32544 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.29973 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.28819 | 	Val Loss: 0.00088
#
# 	Train Loss: 0.27731 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.25183 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.28106 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.23026 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.18402 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.20555 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.23436 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.25975 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.27221 | 	Val Loss: 0.00078
#
# 	Train Loss: 0.25724 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.22480 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.19770 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.19472 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.22731 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.23012 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.20025 | 	Val Loss: 0.00067
#
# ...
#
# 	Train Loss: 0.26022 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.28592 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.26584 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.21614 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.22470 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.14673 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16127 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.14369 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.10306 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.10546 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.13056 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.17440 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.19880 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.20511 | 	Val Loss: 0.00075
#
# 	Train Loss: 0.24800 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.19332 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.22633 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.20348 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.20166 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.14877 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14810 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.13933 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.13639 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14438 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13494 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.12163 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.13978 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.17273 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.13585 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.15785 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15941 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.14201 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.18075 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.19244 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.20884 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.20044 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.20345 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.15531 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.15287 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.09979 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.09648 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.11577 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.11588 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.11209 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13312 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13617 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12876 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.17165 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.16455 | 	Val Loss: 0.00055
#
# 	Train Loss: 0.17170 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.16065 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14799 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.15660 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.14548 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.14097 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.11777 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.12706 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.13263 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.10982 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.12493 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11434 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.09276 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.10481 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.14667 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.14575 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.16289 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16409 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.16432 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.17581 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.15415 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.13524 | 	Val Loss: 0.00037
#
# (3590, 11, 5)
# 	Train Loss: 24.23139 | 	Val Loss: 0.01172
#
# 	Train Loss: 6.44407 | 	Val Loss: 0.00469
#
# 	Train Loss: 1.06517 | 	Val Loss: 0.00411
#
# 	Train Loss: 0.65696 | 	Val Loss: 0.00370
#
# 	Train Loss: 0.51206 | 	Val Loss: 0.00348
#
# 	Train Loss: 0.45144 | 	Val Loss: 0.00348
#
# 	Train Loss: 0.48142 | 	Val Loss: 0.00383
#
# 	Train Loss: 0.70063 | 	Val Loss: 0.00461
#
# 	Train Loss: 1.35744 | 	Val Loss: 0.00504
#
# 	Train Loss: 1.99102 | 	Val Loss: 0.00354
#
# 	Train Loss: 1.23669 | 	Val Loss: 0.00227
#
# 	Train Loss: 0.60662 | 	Val Loss: 0.00169
#
# 	Train Loss: 0.38831 | 	Val Loss: 0.00145
#
# 	Train Loss: 0.31706 | 	Val Loss: 0.00133
#
# 	Train Loss: 0.29955 | 	Val Loss: 0.00129
#
# 	Train Loss: 0.31348 | 	Val Loss: 0.00131
#
# 	Train Loss: 0.35393 | 	Val Loss: 0.00139
#
# 	Train Loss: 0.41433 | 	Val Loss: 0.00148
#
# 	Train Loss: 0.47507 | 	Val Loss: 0.00154
#
# 	Train Loss: 0.50676 | 	Val Loss: 0.00152
#
# 	Train Loss: 0.49401 | 	Val Loss: 0.00143
#
# 	Train Loss: 0.45039 | 	Val Loss: 0.00131
#
# 	Train Loss: 0.40095 | 	Val Loss: 0.00121
#
# 	Train Loss: 0.36097 | 	Val Loss: 0.00113
#
# 	Train Loss: 0.33410 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.31869 | 	Val Loss: 0.00105
#
# 	Train Loss: 0.31204 | 	Val Loss: 0.00104
#
# 	Train Loss: 0.31166 | 	Val Loss: 0.00104
#
# 	Train Loss: 0.31535 | 	Val Loss: 0.00105
#
# 	Train Loss: 0.32092 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.32610 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.32878 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.32629 | 	Val Loss: 0.00105
#
# 	Train Loss: 0.31698 | 	Val Loss: 0.00107
#
# 	Train Loss: 0.35322 | 	Val Loss: 0.00100
#
# 	Train Loss: 0.33345 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.28514 | 	Val Loss: 0.00084
#
# 	Train Loss: 0.24890 | 	Val Loss: 0.00089
#
# 	Train Loss: 0.27235 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.30457 | 	Val Loss: 0.00111
#
# 	Train Loss: 0.32612 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.25737 | 	Val Loss: 0.00076
#
# 	Train Loss: 0.23335 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.25749 | 	Val Loss: 0.00098
#
# 	Train Loss: 0.27630 | 	Val Loss: 0.00091
#
# 	Train Loss: 0.28303 | 	Val Loss: 0.00086
#
# 	Train Loss: 0.26195 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.20818 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.21076 | 	Val Loss: 0.00086
#
# 	Train Loss: 0.27846 | 	Val Loss: 0.00103
#
# 	Train Loss: 0.30306 | 	Val Loss: 0.00107
#
# 	Train Loss: 0.32030 | 	Val Loss: 0.00069
#
# 	Train Loss: 0.21715 | 	Val Loss: 0.00081
#
# 	Train Loss: 0.25076 | 	Val Loss: 0.00095
#
# 	Train Loss: 0.26914 | 	Val Loss: 0.00090
#
# 	Train Loss: 0.26573 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.20854 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.16945 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.20021 | 	Val Loss: 0.00077
#
# 	Train Loss: 0.23749 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.25186 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.25133 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.16578 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.19149 | 	Val Loss: 0.00079
#
# 	Train Loss: 0.24141 | 	Val Loss: 0.00087
#
# 	Train Loss: 0.25829 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.23885 | 	Val Loss: 0.00057
#
# 	Train Loss: 0.16614 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.21223 | 	Val Loss: 0.00078
#
# 	Train Loss: 0.23224 | 	Val Loss: 0.00082
#
# 	Train Loss: 0.25225 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.17974 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.16419 | 	Val Loss: 0.00067
#
# 	Train Loss: 0.20569 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.20924 | 	Val Loss: 0.00072
#
# 	Train Loss: 0.22413 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.14439 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.12208 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.17833 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.21780 | 	Val Loss: 0.00074
#
# 	Train Loss: 0.23106 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.18978 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15510 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.20064 | 	Val Loss: 0.00071
#
# 	Train Loss: 0.21128 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.22818 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.13940 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13955 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.20050 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.18950 | 	Val Loss: 0.00066
#
# 	Train Loss: 0.20743 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.12317 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14316 | 	Val Loss: 0.00059
#
# 	Train Loss: 0.18609 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.18817 | 	Val Loss: 0.00063
#
# 	Train Loss: 0.19762 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.12247 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12765 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.19830 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.17702 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.20308 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.13467 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16206 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.17545 | 	Val Loss: 0.00061
#
# 	Train Loss: 0.18695 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.14934 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11537 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.14237 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17391 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.14877 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.16573 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.10441 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.12143 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.16540 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.17288 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.19169 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13155 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.16115 | 	Val Loss: 0.00058
#
# 	Train Loss: 0.16149 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.17077 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.12324 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10418 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.14222 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.14080 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.15129 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.13291 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.10143 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.13805 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15465 | 	Val Loss: 0.00052
#
# 	Train Loss: 0.16263 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14678 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.12075 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.15618 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.14287 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.15212 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.10580 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.12303 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.13883 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.13340 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13794 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.09869 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.09673 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.12482 | 	Val Loss: 0.00047
#
# 	Train Loss: 0.14470 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.14300 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14671 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.10454 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.11571 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.14202 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.12681 | 	Val Loss: 0.00039
#
# (3590, 11, 5)
# 	Train Loss: 26.43510 | 	Val Loss: 0.01466
#
# 	Train Loss: 7.71160 | 	Val Loss: 0.00348
#
# 	Train Loss: 1.03491 | 	Val Loss: 0.00390
#
# 	Train Loss: 0.78232 | 	Val Loss: 0.00398
#
# 	Train Loss: 0.76898 | 	Val Loss: 0.00437
#
# 	Train Loss: 0.94968 | 	Val Loss: 0.00490
#
# 	Train Loss: 1.39289 | 	Val Loss: 0.00497
#
# 	Train Loss: 1.69851 | 	Val Loss: 0.00384
#
# 	Train Loss: 1.26079 | 	Val Loss: 0.00264
#
# 	Train Loss: 0.75069 | 	Val Loss: 0.00203
#
# 	Train Loss: 0.50683 | 	Val Loss: 0.00176
#
# 	Train Loss: 0.41160 | 	Val Loss: 0.00164
#
# 	Train Loss: 0.38468 | 	Val Loss: 0.00161
#
# 	Train Loss: 0.39942 | 	Val Loss: 0.00166
#
# 	Train Loss: 0.44558 | 	Val Loss: 0.00173
#
# 	Train Loss: 0.50713 | 	Val Loss: 0.00177
#
# 	Train Loss: 0.55402 | 	Val Loss: 0.00172
#
# 	Train Loss: 0.55910 | 	Val Loss: 0.00160
#
# 	Train Loss: 0.52305 | 	Val Loss: 0.00144
#
# 	Train Loss: 0.46956 | 	Val Loss: 0.00131
#
# 	Train Loss: 0.42048 | 	Val Loss: 0.00121
#
# 	Train Loss: 0.38477 | 	Val Loss: 0.00114
#
# 	Train Loss: 0.36254 | 	Val Loss: 0.00110
#
# 	Train Loss: 0.35092 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.34675 | 	Val Loss: 0.00107
#
# 	Train Loss: 0.34719 | 	Val Loss: 0.00107
#
# 	Train Loss: 0.34966 | 	Val Loss: 0.00107
#
# 	Train Loss: 0.35179 | 	Val Loss: 0.00106
#
# 	Train Loss: 0.35165 | 	Val Loss: 0.00104
#
# 	Train Loss: 0.34837 | 	Val Loss: 0.00102
#
# 	Train Loss: 0.34207 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.33244 | 	Val Loss: 0.00096
#
# 	Train Loss: 0.32259 | 	Val Loss: 0.00093
#
# 	Train Loss: 0.31076 | 	Val Loss: 0.00085
#
# 	Train Loss: 0.27900 | 	Val Loss: 0.00073
#
# 	Train Loss: 0.24388 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.17361 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.15050 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.15069 | 	Val Loss: 0.00054
#
# 	Train Loss: 0.14864 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.14906 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.18130 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.20895 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.20550 | 	Val Loss: 0.00062
#
# 	Train Loss: 0.19057 | 	Val Loss: 0.00068
#
# 	Train Loss: 0.25955 | 	Val Loss: 0.00120
#
# 	Train Loss: 0.46047 | 	Val Loss: 0.00186
#
# 	Train Loss: 0.64582 | 	Val Loss: 0.00141
#
# 	Train Loss: 0.64310 | 	Val Loss: 0.00145
#
# 	Train Loss: 0.52906 | 	Val Loss: 0.00099
#
# 	Train Loss: 0.32178 | 	Val Loss: 0.00064
#
# 	Train Loss: 0.20546 | 	Val Loss: 0.00053
#
# 	Train Loss: 0.16427 | 	Val Loss: 0.00049
#
# 	Train Loss: 0.14519 | 	Val Loss: 0.00046
#
# 	Train Loss: 0.13439 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.12650 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.11991 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.12829 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.13644 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.16285 | 	Val Loss: 0.00051
#
# 	Train Loss: 0.18634 | 	Val Loss: 0.00060
#
# 	Train Loss: 0.24997 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.37508 | 	Val Loss: 0.00108
#
# 	Train Loss: 0.39535 | 	Val Loss: 0.00092
#
# 	Train Loss: 0.33014 | 	Val Loss: 0.00081
#
# 	Train Loss: 0.29028 | 	Val Loss: 0.00083
#
# 	Train Loss: 0.27262 | 	Val Loss: 0.00070
#
# 	Train Loss: 0.21984 | 	Val Loss: 0.00056
#
# 	Train Loss: 0.17504 | 	Val Loss: 0.00050
#
# 	Train Loss: 0.15177 | 	Val Loss: 0.00048
#
# 	Train Loss: 0.14169 | 	Val Loss: 0.00045
#
# 	Train Loss: 0.13750 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.14731 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14828 | 	Val Loss: 0.00044
#
# 	Train Loss: 0.14964 | 	Val Loss: 0.00043
#
# 	Train Loss: 0.15462 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.14833 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.14614 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.13791 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.13656 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13482 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.13765 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13859 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.13973 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13898 | 	Val Loss: 0.00040
#
# 	Train Loss: 0.13793 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13694 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13652 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13661 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13675 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13666 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13621 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13548 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13451 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13351 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13381 | 	Val Loss: 0.00042
#
# 	Train Loss: 0.13245 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13105 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13237 | 	Val Loss: 0.00041
#
# 	Train Loss: 0.13226 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12594 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12173 | 	Val Loss: 0.00038
#
# 	Train Loss: 0.12095 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12280 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12540 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12918 | 	Val Loss: 0.00039
#
# 	Train Loss: 0.12542 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11957 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.11503 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.11501 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.11744 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.11940 | 	Val Loss: 0.00036
#
# 	Train Loss: 0.11760 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.11612 | 	Val Loss: 0.00034
#
# 	Train Loss: 0.11142 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.10332 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.10543 | 	Val Loss: 0.00035
#
# 	Train Loss: 0.11306 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12395 | 	Val Loss: 0.00037
#
# 	Train Loss: 0.12615 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.11020 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.09233 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.09031 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.10052 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.10864 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.10759 | 	Val Loss: 0.00032
#
# 	Train Loss: 0.10253 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.08918 | 	Val Loss: 0.00027
#
# 	Train Loss: 0.09036 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.11245 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.09017 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.09235 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.09937 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.09948 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.09410 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.08971 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.09112 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.09398 | 	Val Loss: 0.00031
#
# 	Train Loss: 0.09265 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.08773 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.09783 | 	Val Loss: 0.00033
#
# 	Train Loss: 0.10281 | 	Val Loss: 0.00030
#
# 	Train Loss: 0.09587 | 	Val Loss: 0.00025
#
# 	Train Loss: 0.08215 | 	Val Loss: 0.00024
#
# 	Train Loss: 0.08176 | 	Val Loss: 0.00026
#
# 	Train Loss: 0.08616 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.08902 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.08958 | 	Val Loss: 0.00028
#
# 	Train Loss: 0.09063 | 	Val Loss: 0.00029
#
# 	Train Loss: 0.09743 | 	Val Loss: 0.00032

# %%
idx = 0
plt.figure(figsize=(15,5), dpi=200)

plt.plot(
    np.arange(y_train_nd.shape[0], y_train_nd.shape[0] + y_test_nd.shape[0]),
    y_test_nd[:, idx],
    color='blue',
    label='test target'
)

for sma_window in ress.keys():
    plt.plot(
        np.arange(y_train_nd.shape[0], y_train_nd.shape[0] + ress[sma_window].shape[0]),
        ress[sma_window],
        label=f'SMA{sma_window} prediction'
    )

plt.title('future ETHUSDT prices (With SMAn)')
plt.xlabel('time (Day count)')
plt.ylabel('Price (Norm)')
plt.legend(loc='best')
plt.plot()
# Out:
# []
